# %%
import numpy as np
import pandas as pd
country=['Taiwan','Australia','Ireland','Australia','Ireland','Taiwan']
age=[25,30,45,35,22,36]
salary=[20000,32000,59000,60000,43000,52000]
dic={"(A)Monday1":age,"(B)ampm1":country,"(C)local":country,"(D)time":country,"(E)local":country,"(F)time":country,}
data=pd.DataFrame(dic)
data
# Out:
#    (A)Monday1   (B)ampm1   (C)local    (D)time   (E)local    (F)time
# 0          25     Taiwan     Taiwan     Taiwan     Taiwan     Taiwan
# 1          30  Australia  Australia  Australia  Australia  Australia
# 2          45    Ireland    Ireland    Ireland    Ireland    Ireland
# 3          35  Australia  Australia  Australia  Australia  Australia
# 4          22    Ireland    Ireland    Ireland    Ireland    Ireland
# 5          36     Taiwan     Taiwan     Taiwan     Taiwan     Taiwan

# %%
import pandas as pd
import csv
import numpy as np
df = pd.read_csv('C:/pythonwork/2.csv',encoding='big5')

df.head()
ntext=[]
text=[]
daytemp=[0,0,0,0,0]
timetemp=[0,0,0]
txttemp=[]
A=''
B=''
C=''
f = open('final2.txt', "r",encoding='big5')
for line in f:
    text.append(line)
for co in range(1):
    ntext=text[8].split(',')
    
    for w in range(len(ntext)):
        if '星期一' in ntext[w]:
            daytemp[0]=w
        elif '星期二' in ntext[w]:
             daytemp[1]=w
        elif '星期三' in ntext[w]:
            daytemp[2]=w
        elif '星期四' in ntext[w]:
             daytemp[3]=w
        elif '星期五' in ntext[w]:
             daytemp[4]=w
    
    for w in range (0,len(daytemp)):
        if daytemp[w]!=0:
            for ww in range(daytemp[w],daytemp[w]+15) :
                if ww == len(ntext):
                      break
                if w == len(daytemp)-1:
                      pass
                elif ww == daytemp[w+1]:
                      break

              
                if '上午' in ntext[ww]:
                      timetemp[0]=ww
                if '下午' in ntext[ww]:
                      timetemp[1]=ww
                if '晚上' in ntext[ww]:
                      timetemp[2]=ww
                  #先找禮拜一的
            print(timetemp)
        if daytemp[w]==0:
            A='x,x,x,x'
            B='x,x,x,x'
            C='x,x,x,x'
        if timetemp[0]==0:
            A='x,x,x,x'
        if timetemp[1]==0:
            B='x,x,x,x'
        if timetemp[2]==0:
            C='x,x,x,x' 
        if timetemp[0]==0 and timetemp[1]==0 and timetemp[2]==0:
            break
        if timetemp[0]>0 and timetemp[1]>0 and timetemp[2]>0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                     for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if  '\n' in ntext[timetemp[ii]+find]or'等待時間' in ntext[timetemp[ii]+find]or'晚餐' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find]or'早餐' in ntext[timetemp[ii]+find]or'下午' in ntext[timetemp[ii]+find] or '晚上' in ntext[timetemp[ii]+find]or'星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+',' 
            df[ntext[daytemp[w]]]=[A,B,C]
        if timetemp[0]==0 or timetemp[1]==0 or timetemp[2]==0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if '星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find] or  '下午' in ntext[timetemp[ii]+find] or  '晚上' in ntext[timetemp[ii]+find] or  '早餐' in ntext[timetemp[ii]+find] or  '晚餐' in ntext[timetemp[ii]+find] or  '\n' in ntext[timetemp[ii]+find] or  '等候時間' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+','
            df[ntext[daytemp[w]]]=[A,B,C]

        A=''
        B=''
        C=''
df=df.rename(columns={'TIME':ntext[0]})



print(daytemp)
print(ntext)
df.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b2a56bc44657> in <module>()
#       2 import csv
#       3 import numpy as np
# ----> 4 df = pd.read_csv('C:/pythonwork/2.csv',encoding='big5')
#       5
#       6 df.head()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:/pythonwork/2.csv' does not exist: b'C:/pythonwork/2.csv'

# %%
import pandas as pd
import csv
import numpy as np


df = pd.read_csv('2.csv',encoding='big5',delimiter="\t")
df1=pd.read_csv('122.csv',encoding='utf-8',delimiter="\t")
ntext=[]
text=[]
daytemp=[0,0,0,0,0]
timetemp=[0,0,0]
txttemp=[]
A=''
B=''
C=''
f = open('final2.txt', "r",encoding='big5')
for line in f:
    text.append(line)
for co in range(len(text)):
    ntext=text[co].split(',')
    for w in range(len(ntext)):
        if '星期一' in ntext[w]:
            daytemp[0]=w
        elif '星期二' in ntext[w]:
             daytemp[1]=w
        elif '星期三' in ntext[w]:
            daytemp[2]=w
        elif '星期四' in ntext[w]:
             daytemp[3]=w
        elif '星期五' in ntext[w]:
             daytemp[4]=w
    
    for w in range (0,len(daytemp)):
        if daytemp[w]!=0:
            for ww in range(daytemp[w],daytemp[w]+15) :
                if ww == len(ntext):
                      break
                if w == len(daytemp)-1:
                      pass
                elif ww == daytemp[w+1]:
                      break   
                if '上午' in ntext[ww]:
                      timetemp[0]=ww
                if '下午' in ntext[ww]:
                      timetemp[1]=ww
                if '晚上' in ntext[ww]:
                      timetemp[2]=ww
                  #先找禮拜一的
            print(timetemp)
        if daytemp[w]==0:
            A='x,x,x,x'
            B='x,x,x,x'
            C='x,x,x,x'
        if timetemp[0]==0:
            A='x,x,x,x'
        if timetemp[1]==0:
            B='x,x,x,x'
        if timetemp[2]==0:
            C='x,x,x,x' 
        if timetemp[0]==0 and timetemp[1]==0 and timetemp[2]==0:
            break
        if timetemp[0]>0 and timetemp[1]>0 and timetemp[2]>0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if  '\n' in ntext[timetemp[ii]+find]or'等待時間' in ntext[timetemp[ii]+find]or'晚餐' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find]or'早餐' in ntext[timetemp[ii]+find]or'下午' in ntext[timetemp[ii]+find] or '晚上' in ntext[timetemp[ii]+find]or'星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+',' 
                    print(ntext[daytemp[w]])
                    print(A)
            df[ntext[daytemp[w]]]=[A,B,C]
        if timetemp[0]==0 or timetemp[1]==0 or timetemp[2]==0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if '星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find] or  '下午' in ntext[timetemp[ii]+find] or  '晚上' in ntext[timetemp[ii]+find] or  '早餐' in ntext[timetemp[ii]+find] or  '晚餐' in ntext[timetemp[ii]+find] or  '\n' in ntext[timetemp[ii]+find] or  '等候時間' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+','
            df[ntext[daytemp[w]]]=[A,B,C]
            
    
        A=''
        B=''
        C=''
    df=df.rename(columns={'TIME':ntext[0]})
    df = pd.concat([df,df1],axis=0)
    df1=df
df.to_csv('122.csv',encoding='big5')



print(daytemp)
print(ntext)
# Out:
# [2, 5, 8]
# 星期一
# [S資訊管理大樓],[0-5分鐘],
# 星期一
# [S資訊管理大樓],[0-5分鐘],
# 星期一
# [S資訊管理大樓],[0-5分鐘],
# [11, 17, 20]
# 星期二
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 星期二
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 星期二
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# [23, 26, 28]
# 星期三
# [EE綜合教學大樓],[5-10分鐘],
# 星期三
# [EE綜合教學大樓],[5-10分鐘],
# 星期三
# [EE綜合教學大樓],[5-10分鐘],
# [31, 34, 36]
# 星期四
# [S資訊管理大樓],[0-5分鐘],
# 星期四
# [S資訊管理大樓],[0-5分鐘],
# 星期四
# [S資訊管理大樓],[0-5分鐘],
# [39, 42, 44]
# 星期五
# [S資訊管理大樓],[0-5分鐘],
# 星期五
# [S資訊管理大樓],[0-5分鐘],
# 星期五
# [S資訊管理大樓],[0-5分鐘],
# [2, 5, 44]
# 星期一
# [體育一館],[0-5分鐘],
# 星期一
# [體育一館],[0-5分鐘],
# 星期一
# [體育一館],[0-5分鐘],
# C:\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:100: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f35236340484> in <module>()
#      76                     print(ntext[daytemp[w]])
#      77                     print(A)
# ---> 78             df[ntext[daytemp[w]]]=[A,B,C]
#      79         if timetemp[0]==0 or timetemp[1]==0 or timetemp[2]==0:
#      80             for ii in range(len(timetemp)):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# -> 3630             value = sanitize_index(value, self.index, copy=False)
#    3631             if not isinstance(value, (np.ndarray, Index)):
#    3632                 if isinstance(value, list) and len(value) > 0:
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     517
#     518     if len(data) != len(index):
# --> 519         raise ValueError('Length of values does not match length of index')
#     520
#     521     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
df1=pd.read_csv('C:/Users/lin/122.csv',encoding='big5')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-ba1bd6068827> in <module>()
# ----> 1 df1=pd.read_csv('C:/Users/lin/122.csv',encoding='big5')
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ad9df82-6c56-44b3-970c-00b45750764a" name="files[]" multiple disabled />
#      <output id="result-6ad9df82-6c56-44b3-970c-00b45750764a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final2.txt to final2.txt

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit([1, 2, 2, 6])
le.classes_
le.transform([1, 1, 2, 6]) 
le.inverse_transform([0, 0, 1, 2])
# Out:
# array([1, 1, 2, 6])

# %%
le = preprocessing.LabelEncoder()
le.fit(["paris", "paris", "tokyo", "amsterdam"])
le.transform(["tokyo", "tokyo", "paris"]) 
list(le.inverse_transform([2, 2, 1]))
# Out:
# ['tokyo', 'tokyo', 'paris']

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
enc = OneHotEncoder()
lb = LabelEncoder()
tmp = lb.fit_transform([123,456,789])
print(tmp)#输出LabelEncoder的结果
enc.fit(tmp.reshape(-1,1))#将LabelEncoder的结果作为OneHotEncoder特征输入
x_train = enc.transform(lb.transform([123,789]).reshape(-1, 1))
#输出特征[123,789]的OneHotEncoder的编码结果
print(x_train)
# Out:
# [0 1 2]
#   (0, 0)	1.0
#   (1, 2)	1.0
# C:\Users\schoolpc\.conda\envs\tensorflow\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
timetemp=[1,0,1]

if timetemp[0]>0 and timetemp[1]>0 and timetemp[2]>0:
    print("ooooooo")

# %%
import pandas as pd
import csv
import numpy as np


df = pd.read_csv('2.csv',encoding='big5')
ntext=[]
text=[]
daytemp=[0,0,0,0,0]
timetemp=[0,0,0]

df1 = pd.DataFrame()
txttemp=[]
A=''
B=''
C=''
f = open('final2.txt', "r",encoding='big5')
for line in f:
    text.append(line)
for co in range(len(text)):
    ntext=text[co].split(',')
    for w in range(len(ntext)):
        if '星期一' in ntext[w]:
            daytemp[0]=w
        elif '星期二' in ntext[w]:
             daytemp[1]=w
        elif '星期三' in ntext[w]:
            daytemp[2]=w
        elif '星期四' in ntext[w]:
             daytemp[3]=w
        elif '星期五' in ntext[w]:
             daytemp[4]=w
    
    for w in range (0,len(daytemp)):
        if daytemp[w]!=0:
            for ww in range(daytemp[w],daytemp[w]+15) :
                if ww == len(ntext):
                      break
                if w == len(daytemp)-1:
                      pass
                elif ww == daytemp[w+1]:
                      break   
                if '上午' in ntext[ww]:
                      timetemp[0]=ww
                if '下午' in ntext[ww]:
                      timetemp[1]=ww
                if '晚上' in ntext[ww]:
                      timetemp[2]=ww
                  #先找禮拜一的
            print(timetemp)
        if daytemp[w]==0:
            A='x,x,x,x'
            B='x,x,x,x'
            C='x,x,x,x'
        if timetemp[0]==0:
            A='x,x,x,x'
        if timetemp[1]==0:
            B='x,x,x,x'
        if timetemp[2]==0:
            C='x,x,x,x' 
        if timetemp[0]==0 and timetemp[1]==0 and timetemp[2]==0:
            break
        if timetemp[0]>0 and timetemp[1]>0 and timetemp[2]>0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):

                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if  '\n' in ntext[timetemp[ii]+find]or'等待時間' in ntext[timetemp[ii]+find]or'晚餐' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find]or'早餐' in ntext[timetemp[ii]+find]or'下午' in ntext[timetemp[ii]+find] or '晚上' in ntext[timetemp[ii]+find]or'星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+',' 
            df[ntext[daytemp[w]]]=[A,B,C]
        if timetemp[0]==0 or timetemp[1]==0 or timetemp[2]==0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if '星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find] or  '下午' in ntext[timetemp[ii]+find] or  '晚上' in ntext[timetemp[ii]+find] or  '早餐' in ntext[timetemp[ii]+find] or  '晚餐' in ntext[timetemp[ii]+find] or  '\n' in ntext[timetemp[ii]+find] or  '等候時間' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+','
            df[ntext[daytemp[w]]]=[A,B,C]
            
    
        A=''
        B=''
        C=''
    daytemp=[0,0,0,0,0]
    timetemp=[0,0,0]
    df=df.rename(columns={'TIME':ntext[0]})
    print(df)
    df = pd.concat([df,df1],axis=0)
    df1=df
    df=pd.DataFrame()
    
df.head

print(df1)

print(daytemp)
print(ntext)
df1.to_csv('122.csv',encoding='big5')
# Out:
# [2, 5, 8]
# [11, 17, 20]
# [23, 26, 28]
# [31, 34, 36]
# [39, 42, 44]
#   資訊學院                 星期一                                     星期二  \
# 0   上午  [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1   下午   [AA科技大樓],[0-5分鐘],                      [S資訊管理大樓],[0-5分鐘],
# 2   晚上             [不在學校],                                 [不在學校],
#
#                     星期三                 星期四                 星期五
# 0  [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1               [不在學校],             [不在學校],             [不在學校],
# 2               [不在學校],             [不在學校],            [不在學校],,
# [2, 5, 0]
# [9, 12, 15]
# [19, 22, 25]
# [29, 32, 25]
# [36, 39, 25]
#                星期一                 星期二               星期三                 星期四  \
# 0  [體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],   [體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1  [體育一館],[0-5分鐘],    [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],     [體育一館],[0-5分鐘],
# 2          x,x,x,x    [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],    [M設計大樓],[0-5分鐘],
#
#                   星期五
# 0  [S資訊管理大樓],[0-5分鐘],
# 1    [體育一館],[0-5分鐘],,
# 2    [M設計大樓],[0-5分鐘],
# [2, 5, 0]
# [12, 15, 0]
# [22, 25, 0]
# [32, 35, 0]
# [42, 45, 0]
#                                   星期一                                 星期二  \
# 0                  [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             x,x,x,x                             x,x,x,x
#
#                                   星期三                                 星期四  \
# 0                  [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             x,x,x,x                             x,x,x,x
#
#                                   星期五
# 0                  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             x,x,x,x
# [2, 0, 0]
# [2, 0, 0]
# [10, 0, 0]
# [10, 0, 0]
# [18, 0, 0]
#                  星期一                星期二                  星期三  \
# 0  [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1            x,x,x,x            x,x,x,x              x,x,x,x
# 2            x,x,x,x            x,x,x,x              x,x,x,x
#
#                    星期四                星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[0-5分鐘],
# 1              x,x,x,x            x,x,x,x
# 2              x,x,x,x            x,x,x,x
# [2, 5, 11]
# [14, 17, 23]
# [26, 29, 35]
# [38, 41, 47]
# [50, 53, 59]
#                                        星期一                              星期二  \
# 0                        [AA科技大樓],[0-5分鐘],                [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 2                                  [不在學校],                          [不在學校],
#
#                                星期三                                      星期四  \
# 0                [AA科技大樓],[0-5分鐘],                        [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                          [不在學校],                                  [不在學校],
#
#                                        星期五
# 0                        [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                                 [不在學校],,
# [2, 5, 0]
# [9, 12, 0]
# [16, 22, 0]
# [16, 22, 0]
# [27, 22, 0]
#                  星期一                 星期二  \
# 0  [AA科技大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2            x,x,x,x             x,x,x,x
#
#                                       星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1                      [S資訊管理大樓],[0-5分鐘],
# 2                                 x,x,x,x
#
#                                       星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,
# 1                      [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2                                 x,x,x,x             x,x,x,x
# [2, 8, 11]
# [16, 22, 25]
# [30, 36, 39]
# [30, 36, 44]
# [30, 36, 49]
#                                       星期一  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                     [S資訊管理大樓],[5-10分鐘],
# 2                         [不在學校],,[不在學校],
#
#                                       星期二  \
# 0  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [AA科技大樓],[5-10分鐘],
# 2                         [不在學校],,[不在學校],
#
#                                        星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                        星期四  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                        星期五
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                         [不在學校],,[不在學校],,
# [2, 8, 11]
# [14, 20, 23]
# [26, 32, 35]
# [38, 44, 47]
# [50, 56, 59]
#                             星期一                           星期二  \
# 0  [不在學校],,,[S資訊管理大樓],[5-10分鐘],  [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1            [AA科技大樓],[5-10分鐘],            [AA科技大樓],[5-10分鐘],
# 2                       [不在學校],                       [不在學校],
#
#                             星期三                           星期四  \
# 0  [不在學校],,,[S資訊管理大樓],[5-10分鐘],  [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1            [AA科技大樓],[5-10分鐘],            [AA科技大樓],[5-10分鐘],
# 2                       [不在學校],                       [不在學校],
#
#                             星期五
# 0  [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1            [AA科技大樓],[5-10分鐘],
# 2                      [不在學校],,
# [0, 2, 5]
# [0, 8, 11]
# [14, 8, 17]
# [14, 8, 17]
# [23, 8, 26]
#                  星期一                 星期二                  星期三  \
# 0            x,x,x,x             x,x,x,x  [EE綜合教學大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2            [不在學校],             [不在學校],              [不在學校],
#
#                    星期四                 星期五
# 0  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2              [不在學校],             [不在學校],
# [2, 5, 8]
# [11, 14, 17]
# [20, 23, 25]
# [28, 31, 33]
# [28, 31, 33]
#                   星期一                   星期二                   星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],
# 1   [AA科技大樓],[0-5分鐘],    [S資訊管理大樓],[0-5分鐘],               [不在學校],
# 2             [不在學校],               [不在學校],               [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],             [不在學校],
# 2             [不在學校],             [不在學校],
# [2, 5, 8]
# [11, 14, 17]
# [20, 23, 25]
# [28, 31, 33]
# [28, 31, 33]
#                   星期一                   星期二                   星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],
# 1   [AA科技大樓],[0-5分鐘],    [S資訊管理大樓],[0-5分鐘],               [不在學校],
# 2             [不在學校],               [不在學校],               [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],             [不在學校],
# 2             [不在學校],             [不在學校],
# [2, 8, 14]
# [20, 26, 32]
# [38, 44, 50]
# [56, 62, 68]
# [74, 80, 86]
#                                     星期一                                   星期二  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1                [二餐],[0-5分鐘],,[不在學校],,                [二餐],[0-5分鐘],,[不在學校],,
# 2             [不在學校],,[AA科技大樓],[0-5分鐘],             [不在學校],,[AA科技大樓],[0-5分鐘],
#
#                                     星期三                                   星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1                [二餐],[0-5分鐘],,[不在學校],,                [二餐],[0-5分鐘],,[不在學校],,
# 2             [不在學校],,[AA科技大樓],[0-5分鐘],             [不在學校],,[AA科技大樓],[0-5分鐘],
#
#                                     星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1                [二餐],[0-5分鐘],,[不在學校],,
# 2            [不在學校],,[AA科技大樓],[0-5分鐘],,
# [2, 8, 14]
# [19, 25, 31]
# [36, 40, 44]
# [49, 55, 60]
# [65, 69, 73]
#                                       星期一  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                         [不在學校],,[不在學校],
#
#                                       星期二              星期三  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],
# 2                         [不在學校],,[不在學校],  [不在學校],,[不在學校],
#
#                                      星期四               星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],   [不在學校],,[不在學校],
# 1            [S資訊管理大樓],[5-10分鐘],,[不在學校],   [不在學校],,[不在學校],
# 2                        [不在學校],,[不在學校],  [不在學校],,[不在學校],,
# [2, 8, 14]
# [17, 23, 29]
# [36, 23, 43]
# [47, 23, 43]
# [47, 23, 43]
#                                    星期一  \
# 0  [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# 2                            [BB社科大樓],
#
#                                          星期二  \
# 0    [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[10-15分鐘],,[EE綜合教學大樓],[10-15分鐘],
#
#                                          星期三  \
# 0  [S資訊管理大樓],[10-15分鐘],,[P觀光語文大樓],[10-15分鐘],
# 1      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                        [P觀光語文大樓],[5-10分鐘],
#
#                                      星期四  \
# 0                              [AA科技大樓],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [P觀光語文大樓],[5-10分鐘],
#
#                                      星期五
# 0                              [AA科技大樓],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [P觀光語文大樓],[5-10分鐘],
# [2, 4, 9]
# [13, 16, 21]
# [24, 27, 32]
# [36, 39, 42]
# [45, 47, 49]
#                               星期一                              星期二  \
# 0                         [不在學校],                  [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[S資訊管理大樓],  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],
# 2              [S資訊管理大樓],[0-5分鐘],                          [不在學校],
#
#                             星期三                  星期四       星期五
# 0             [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],   [不在學校],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],  [CC資訊網路大樓],[0-5分鐘],   [不在學校],
# 2             [AA科技大樓],[0-5分鐘],              [不在學校],  [不在學校],,
# [0, 2, 5]
# [0, 9, 15]
# [19, 22, 15]
# [26, 29, 15]
# [33, 29, 15]
#                      星期一                                         星期二  \
# 0                x,x,x,x                                     x,x,x,x
# 1    [S資訊管理大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[10-15分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],                         [AA科技大樓],[10-15分鐘],
#
#                    星期三                  星期四                   星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,
# 1  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],
# 2  [AA科技大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],   [AA科技大樓],[10-15分鐘],
# [2, 8, 14]
# [20, 26, 32]
# [37, 43, 49]
# [55, 61, 67]
# [72, 78, 83]
#                                         星期一  \
# 0         [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2               [S資訊管理大樓],[5-10分鐘],,[不在學校],
#
#                                        星期二  \
# 0     [室外籃球場],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                       星期三  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2              [AA科技大樓],[5-10分鐘],,[不在學校],
#
#                                          星期四                           星期五
# 0        [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[不在學校],,
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],              [不在學校],,,[不在學校],
# 2                            [不在學校],,[不在學校],              [不在學校],,[不在學校],,
# [2, 7, 13]
# C:\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:103: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# [20, 25, 31]
# [38, 44, 50]
# [57, 62, 68]
# [75, 80, 86]
#                                     星期一  \
# 0           [AA科技大樓],[0-5分鐘],,[FF國際大樓],
# 1  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# 2          [CC資訊網路大樓],[0-5分鐘],,[不在學校],,
#
#                                      星期二  \
# 0            [EE綜合教學大樓],[0-5分鐘],,[體育一館],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                     星期三  \
# 0        [M設計大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# 2                     [不在學校],,,[不在學校],,
#
#                                      星期四                                   星期五
# 0       [P觀光語文大樓],[0-5分鐘],,[Q行政大樓OR圖書館],           [S資訊管理大樓],[0-5分鐘],,[M設計大樓],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,                     [不在學校],,,[不在學校],,
# [2, 5, 8]
# [12, 15, 18]
# [22, 25, 18]
# [29, 32, 18]
# [36, 32, 18]
#                     星期一                 星期二                 星期三  \
# 0    [AA科技大樓],[5-10分鐘],    [體育一館],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
#
#                   星期四                    星期五
# 0  [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,,
# 1  [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# [2, 5, 8]
# [11, 14, 20]
# [23, 26, 29]
# [32, 35, 38]
# [41, 44, 46]
#                    星期一                                      星期二  \
# 0   [AA科技大樓],[5-10分鐘],                          [體育一館],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2              [不在學校],                                  [不在學校],
#
#                    星期三                  星期四                  星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],              [不在學校],
# 2              [不在學校],              [不在學校],             [不在學校],,
# [2, 5, 8]
# [12, 14, 17]
# [20, 23, 26]
# [30, 33, 36]
# [39, 42, 44]
#                    星期一                  星期二                  星期三  \
# 0             [不在學校],,          [EE綜合教學大樓],  [EE綜合教學大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],              [不在學校],  [CC資訊網路大樓],[0-5分鐘],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],            [不在學校],,
# [2, 5, 8]
# [12, 15, 8]
# [12, 22, 8]
# [26, 29, 8]
# [33, 29, 8]
#                      星期一                                       星期二  \
# 0     [AA科技大樓],[5-10分鐘],                           [體育一館],[0-5分鐘],
# 1     [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],                     [CC資訊網路大樓],[10-15分鐘],
#
#                      星期三                    星期四                    星期五
# 0        [體育一館],[0-5分鐘],    [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],,
# 1    [S資訊管理大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  [CC資訊網路大樓],[10-15分鐘],  [CC資訊網路大樓],[10-15分鐘],
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 84, 90]
#                                          星期一  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 1     [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
#
#                                       星期二  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                        星期四  \
# 0   [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                        [不在學校],,,[不在學校],,
#
#                                       星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                       [不在學校],,,[不在學校],,
# 2                       [不在學校],,,[不在學校],,
# [2, 5, 11]
# [15, 21, 27]
# [31, 37, 27]
# [41, 47, 27]
# [51, 47, 27]
#                                       星期一  \
# 0                      [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2                       [AA科技大樓],[0-5分鐘],
#
#                                      星期二  \
# 0      [體育一館],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                     [S資訊管理大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                      [AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
# [2, 8, 14]
# [19, 25, 31]
# [34, 40, 46]
# [49, 55, 61]
# [64, 70, 76]
#                                      星期一  \
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                   [CC資訊網路大樓],[0-5分鐘],,
#
#                                      星期二  \
# 0  [S資訊管理大樓],[10-15分鐘],,[體育一館],[5-10分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                                [不在學校],
#
#                                      星期三  \
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                                [不在學校],
#
#                                      星期四  \
# 0  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                               [室外籃球場],
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1            [S資訊管理大樓],[0-5分鐘],,[不在學校],,
# 2                               [不在學校],,
# [2, 5, 11]
# [15, 18, 21]
# [25, 28, 31]
# [34, 37, 40]
# [46, 49, 52]
#                                       星期一                星期二  \
# 0                                [不在學校],,    [體育一館],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 2                       [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
#
#                   星期三                        星期四                星期五
# 0  [S資訊管理大樓],[0-5分鐘],         [S資訊管理大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],         [S資訊管理大樓],[0-5分鐘],           [不在學校],,
# 2             [不在學校],  [不在學校],,[室外籃球場],[20分鐘以上],           [不在學校],,
# [2, 7, 11]
# [15, 20, 11]
# [25, 30, 34]
# [38, 43, 34]
# [48, 53, 34]
#                               星期一                           星期二  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],  [體育一館],[10-15分鐘],,[S資訊管理大樓],
# 1           [CC資訊網路大樓],[5-10分鐘],,         [EE綜合教學大樓],[5-10分鐘],,
# 2           [CC資訊網路大樓],[10-15分鐘],         [CC資訊網路大樓],[10-15分鐘],
#
#                                星期三                             星期四  \
# 0  [S資訊管理大樓],[10-15分鐘],,[S資訊管理大樓],  [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],
# 1              [AA科技大樓],[5-10分鐘],,             [AA科技大樓],[5-10分鐘],,
# 2              [AA科技大樓],[10-15分鐘],             [AA科技大樓],[10-15分鐘],
#
#                                星期五
# 0  [S資訊管理大樓],[10-15分鐘],,[S資訊管理大樓],
# 1             [AA科技大樓],[5-10分鐘],,,
# 2              [AA科技大樓],[10-15分鐘],
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 85, 88]
#                                          星期一  \
# 0      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1     [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
#
#                                          星期二  \
# 0           [體育一館],[0-5分鐘],,[體育一館],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                        星期三  \
# 0    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                        [不在學校],,,[不在學校],,
#
#                                        星期四  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1   [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                        [不在學校],,,[不在學校],,
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                                 [不在學校],,
# 2                        [不在學校],,,[不在學校],,
# [2, 5, 0]
# [12, 14, 0]
# [21, 24, 0]
# [28, 31, 0]
# [35, 31, 0]
#                                       星期一  \
# 0                      [AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2                                 x,x,x,x
#
#                                       星期二                  星期三  \
# 0                                 [體育一館],  [AA科技大樓],[10-15分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2                                 x,x,x,x              x,x,x,x
#
#                     星期四                    星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],,
# 1    [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2               x,x,x,x                x,x,x,x
# [2, 5, 11]
# [17, 23, 29]
# [34, 40, 46]
# [51, 57, 63]
# [68, 74, 78]
#                                     星期一  \
# 0                    [S資訊管理大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2           [CC資訊網路大樓],[0-5分鐘],,[不在學校],
#
#                                      星期二  \
# 0        [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                        [不在學校],,[不在學校],
# 2                       [不在學校],,[不在學校],,
# [2, 5, 11]
# [17, 23, 29]
# [35, 41, 47]
# [53, 59, 65]
# [71, 59, 76]
#                                     星期一                                  星期二  \
# 0                     [AA科技大樓],[0-5分鐘],    [體育一館],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                      [不在學校],,[不在學校],,                     [不在學校],,[不在學校],,
#
#                                     星期三                                   星期四  \
# 0   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                      [不在學校],,[不在學校],,                      [不在學校],,[不在學校],,
#
#                                    星期五
# 0          [S資訊管理大樓],[0-5分鐘],,[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                    [不在學校],,[不在學校],,,
# [2, 8, 14]
# [19, 25, 31]
# [36, 42, 47]
# [52, 58, 63]
# [68, 74, 79]
#                                         星期一  \
# 0                         [不在學校],,,[不在學校],,
# 1  [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2                           [不在學校],,[不在學校],
#
#                                        星期二  \
# 0                 [體育一館],[0-5分鐘],,[不在學校],,
# 1  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                       星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1             [S資訊管理大樓],[5-10分鐘],,[不在學校],
# 2                         [不在學校],,[不在學校],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1             [AA科技大樓],[5-10分鐘],,[不在學校],
# 2                        [不在學校],,[不在學校],
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1             [EE綜合教學大樓],[5-10分鐘],,[不在學校],
# 2                         [不在學校],,[不在學校],,
# [2, 5, 0]
# [12, 14, 0]
# [21, 24, 0]
# [28, 31, 0]
# [35, 31, 0]
#                                       星期一  \
# 0                      [AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2                                 x,x,x,x
#
#                                       星期二                  星期三  \
# 0                                 [體育一館],  [AA科技大樓],[10-15分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2                                 x,x,x,x              x,x,x,x
#
#                     星期四                    星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],,
# 1    [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2               x,x,x,x                x,x,x,x
# [2, 4, 7]
# [11, 14, 20]
# [24, 27, 30]
# [33, 36, 39]
# [42, 45, 47]
#                    星期一                                     星期二  \
# 0              [不在學校],                         [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],                       [AA科技大樓],[0-5分鐘],
#
#                   星期三                 星期四                 星期五
# 0   [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],             [不在學校],            [不在學校],,
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 84, 90]
#                                        星期一  \
# 0      [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                          星期二  \
# 0          [體育一館],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[Q行政大樓OR圖書館],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
#
#                                       星期三  \
# 0     [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                       [不在學校],,,[不在學校],,
#
#                                      星期四                                   星期五
# 0    [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],                     [不在學校],,,[不在學校],,
# 2                      [不在學校],,,[不在學校],,                     [不在學校],,,[不在學校],,
# [2, 8, 12]
# [17, 23, 27]
# [32, 38, 42]
# [47, 53, 57]
# [62, 68, 72]
#                                    星期一                                星期二  \
# 0  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1                 [CC資訊網路大樓],[0-5分鐘],,                 [AA科技大樓],[0-5分鐘],,
# 2                  [S資訊管理大樓],[0-5分鐘],,                 [AA科技大樓],[0-5分鐘],,
#
#                                    星期三                                   星期四  \
# 0  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                  [S資訊管理大樓],[0-5分鐘],,                    [AA科技大樓],[0-5分鐘],,
# 2                            [不在學校],,,                             [不在學校],,,
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                              [不在學校],,,
# 2                             [不在學校],,,,
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [58, 64, 70]
# [76, 82, 88]
#                                    星期一                                星期二  \
# 0    [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],    [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
#
#                                   星期三                                星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                    [不在學校],,[不在學校],,                   [不在學校],,[不在學校],,
#
#                                  星期五
# 0  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1           [不在學校],,,[體育一館],[0-5分鐘],
# 2                  [不在學校],,[不在學校],,,
# [2, 4, 7]
# [11, 14, 17]
# [21, 24, 27]
# [30, 33, 36]
# [39, 42, 44]
#                    星期一                  星期二                 星期三  \
# 0              [不在學校],  [EE綜合教學大樓],[0-5分鐘],  [AA科技大樓],[5-10分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],   [AA科技大樓],[5-10分鐘],             [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],            [不在學校],,
# [2, 4, 7]
# [11, 14, 17]
# [21, 23, 25]
# [28, 31, 34]
# [37, 40, 42]
#                   星期一                  星期二      星期三                 星期四  \
# 0             [不在學校],  [EE綜合教學大樓],[0-5分鐘],  [不在學校],  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],  [不在學校],   [AA科技大樓],[0-5分鐘],
# 2   [AA科技大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],  [不在學校],             [不在學校],
#
#                   星期五
# 0  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],
# 2            [不在學校],,
# [2, 8, 0]
# [15, 21, 0]
# [15, 21, 0]
# [29, 35, 0]
# [42, 35, 0]
#                                       星期一  \
# 0    [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2                                 x,x,x,x
#
#                                        星期二  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                                  x,x,x,x
#
#                                        星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                                  x,x,x,x
#
#                                     星期四                                    星期五
# 0  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                               x,x,x,x                                x,x,x,x
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 84, 90]
#                                      星期一  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                      星期二  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                      星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                      [不在學校],,,[不在學校],,
# [0, 2, 5]
# [9, 12, 18]
# [22, 25, 18]
# [29, 32, 18]
# [36, 32, 18]
#                     星期一                                       星期二  \
# 0               x,x,x,x                          [體育一館],[5-10分鐘],
# 1   [S資訊管理大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],                        [AA科技大樓],[5-10分鐘],
#
#                    星期三                  星期四                    星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,,
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2   [AA科技大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# [2, 8, 14]
# [19, 25, 31]
# [36, 42, 48]
# [53, 59, 65]
# [70, 76, 82]
#                                        星期一  \
# 0              [不在學校],,,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                    [CC資訊網路大樓],[5-10分鐘],,
#
#                                        星期二  \
# 0      [體育一館],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                     [S資訊管理大樓],[5-10分鐘],,
#
#                                        星期三  \
# 0   [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                                [不在學校],,,
#
#                                        星期四  \
# 0   [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                                [不在學校],,,
#
#                                       星期五
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                              [不在學校],,,,
# [2, 8, 14]
# [18, 24, 30]
# [34, 40, 46]
# [50, 56, 62]
# [66, 72, 78]
#                                     星期一  \
# 0   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                   [CC資訊網路大樓],[0-5分鐘],
#
#                                        星期二                              星期三  \
# 0          [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],      [S資訊管理大樓],[0-5分鐘],,[不在學校],,
# 2                        [AA科技大樓],[0-5分鐘],                         [不在學校],,
#
#                                    星期四                         星期五
# 0     [S資訊管理大樓],[0-5分鐘],,[二餐],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[不在學校],,
# 1  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],           [不在學校],,,[不在學校],,
# 2                             [不在學校],,                   [不在學校],,,
# [2, 4, 7]
# [11, 15, 21]
# [24, 28, 31]
# [34, 38, 41]
# [44, 48, 51]
#                     星期一                                        星期二  \
# 0               [不在學校],                      [EE綜合教學大樓],[5-10分鐘],,
# 1   [S資訊管理大樓],[5-10分鐘],  [CC資訊網路大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],                                    [不在學校],
#
#                      星期三                   星期四                   星期五
# 0  [EE綜合教學大樓],[5-10分鐘],,  [S資訊管理大樓],[5-10分鐘],,  [S資訊管理大樓],[5-10分鐘],,
# 1    [S資訊管理大樓],[5-10分鐘],    [AA科技大樓],[5-10分鐘],              [不在學校],,
# 2                [不在學校],               [不在學校],              [不在學校],,
# [2, 7, 10]
# [14, 20, 23]
# [27, 32, 37]
# [40, 46, 49]
# [53, 59, 62]
#                               星期一                            星期二  \
# 0  [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],  [體育一館],[0-5分鐘],,[操場],[0-5分鐘],
# 1             [S資訊管理大樓],[5-10分鐘],            [S資訊管理大樓],[5-10分鐘],
# 2             [S資訊管理大樓],[5-10分鐘],            [S資訊管理大樓],[5-10分鐘],
#
#                              星期三                                      星期四  \
# 0  [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1    [不在學校],,[S資訊管理大樓],[5-10分鐘],                      [S資訊管理大樓],[5-10分鐘],
# 2                        [不在學校],                   [Q行政大樓OR圖書館],[5-10分鐘],
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                  [Q行政大樓OR圖書館],[5-10分鐘],,
# [2, 7, 13]
# [20, 25, 31]
# [38, 43, 49]
# [56, 61, 67]
# [74, 79, 85]
#                             星期一                            星期二  \
# 0              [不在學校],,[不在學校],,  [AA科技大樓],,[S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[不在學校],,  [CC資訊網路大樓],[5-10分鐘],,[不在學校],,
# 2  [CC資訊網路大樓],[0-5分鐘],,[不在學校],,              [不在學校],,,[不在學校],,
#
#                            星期三                            星期四  \
# 0             [不在學校],,[不在學校],,  [AA科技大樓],,[S資訊管理大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[不在學校],,    [AA科技大樓],[5-10分鐘],,[不在學校],,
# 2            [不在學校],,,[不在學校],,              [不在學校],,,[不在學校],,
#
#                            星期五
# 0             [不在學校],,[不在學校],,
# 1  [AA科技大樓],[5-10分鐘],,[不在學校],,
# 2            [不在學校],,,[不在學校],,
# [2, 8, 11]
# [15, 21, 27]
# [31, 37, 27]
# [41, 47, 27]
# [51, 47, 27]
#                                         星期一  \
# 0  [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 1                      [CC資訊網路大樓],[5-10分鐘],
# 2                       [CC資訊網路大樓],[0-5分鐘],
#
#                                        星期二  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                        [AA科技大樓],[0-5分鐘],
#
#                                         星期三  \
# 0  [S資訊管理大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                         [AA科技大樓],[0-5分鐘],
#
#                                       星期四                    星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,,
# 1                      [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2                       [AA科技大樓],[0-5分鐘],      [AA科技大樓],[0-5分鐘],
# [2, 5, 8]
# [11, 14, 17]
# [20, 23, 26]
# [30, 33, 36]
# [39, 42, 45]
#                   星期一                 星期二                  星期三  \
# 0     [學校宿舍],[0-5分鐘],  [AA科技大樓],[5-10分鐘],      [學校宿舍],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],  [AA科技大樓],[5-10分鐘],  [EE綜合教學大樓],[0-5分鐘],
# 2             [學校宿舍],             [學校宿舍],   [S資訊管理大樓],[0-5分鐘],
#
#                   星期四                星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 2             [學校宿舍],           [學校宿舍],,
# [2, 5, 8]
# [12, 15, 18]
# [22, 25, 18]
# [29, 32, 18]
# [36, 32, 18]
#                      星期一                    星期二                  星期三  \
# 0  [EE綜合教學大樓],[10-15分鐘],  [EE綜合教學大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],
# 1   [CC資訊網路大樓],[5-10分鐘],   [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],    [AA科技大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],
#
#                     星期四                     星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],,,
# 1    [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# 2   [AA科技大樓],[10-15分鐘],     [AA科技大樓],[10-15分鐘],
# [2, 5, 8]
# [12, 15, 8]
# [19, 22, 8]
# [26, 29, 8]
# [33, 29, 8]
#                    星期一                  星期二                  星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],      [體育一館],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
#
#                    星期四                  星期五
# 0   [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,
# 1    [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
# [0, 2, 4]
# [8, 11, 14]
# [17, 20, 23]
# [26, 29, 32]
# [35, 29, 39]
#                      星期一                   星期二                  星期三  \
# 0                x,x,x,x      [體育一館],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1             [S資訊管理大樓],  [CC資訊網路大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],               [不在學校],              [不在學校],
#
#                   星期四                   星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],,
# 1   [AA科技大樓],[0-5分鐘],     [AA科技大樓],[0-5分鐘],
# 2             [不在學校],              [不在學校],,
# [2, 5, 0]
# [9, 12, 0]
# [15, 18, 0]
# [22, 25, 0]
# [29, 25, 0]
#                     星期一                   星期二                  星期三  \
# 0   [S資訊管理大樓],[5-10分鐘],  [CC資訊網路大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],            [S資訊管理大樓],  [S資訊管理大樓],[5-10分鐘],
# 2               x,x,x,x               x,x,x,x              x,x,x,x
#
#                    星期四                   星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,
# 1  [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],
# 2              x,x,x,x               x,x,x,x
# [0, 2, 5]
# [9, 12, 5]
# [16, 19, 22]
# [26, 29, 22]
# [26, 29, 22]
#                    星期一                  星期二                 星期三  \
# 0              x,x,x,x   [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
#
#                   星期四                 星期五
# 0  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# [2, 7, 10]
# [14, 20, 23]
# [27, 33, 36]
# [40, 46, 49]
# [53, 58, 61]
#                            星期一                                  星期二  \
# 0  [不在學校],,[EE綜合教學大樓],[0-5分鐘],  [體育一館],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1          [EE綜合教學大樓],[0-5分鐘],                   [AA科技大樓],[5-10分鐘],
# 2            [AA科技大樓],[0-5分鐘],                             [不在學校],,
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                    [S資訊管理大樓],[5-10分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期四               星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],,
# 1                      [AA科技大樓],[0-5分鐘],          [不在學校],,
# 2                               [不在學校],,         [不在學校],,,
# [2, 5, 8]
# [12, 15, 18]
# [22, 25, 28]
# [31, 34, 37]
# [40, 43, 46]
#                     星期一                 星期二                  星期三  \
# 0    [AA科技大樓],[5-10分鐘],     [體育一館],[0-5分鐘],   [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],   [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],              [不在學校],
#
#                    星期四                  星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 2              [不在學校],             [不在學校],,
# [2, 5, 0]
# [9, 12, 0]
# [16, 19, 0]
# [23, 26, 0]
# [23, 26, 0]
#                     星期一                   星期二                  星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],      [體育一館],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1   [S資訊管理大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2               x,x,x,x               x,x,x,x              x,x,x,x
#
#                     星期四                   星期五
# 0    [AA科技大樓],[5-10分鐘],    [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  [CC資訊網路大樓],[5-10分鐘],
# 2               x,x,x,x               x,x,x,x
# [2, 4, 6]
# [9, 12, 14]
# [17, 20, 22]
# [25, 28, 30]
# [25, 33, 35]
#            星期一              星期二                星期三                星期四  \
# 0      [不在學校],  [體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],          [不在學校],        [CC資訊網路大樓],            [不在學校],
# 2  [CC資訊網路大樓],          [不在學校],          [AA科技大樓],            [不在學校],
#
#                  星期五
# 0  [AA科技大樓],[0-5分鐘],
# 1            [不在學校],
# 2           [不在學校],,
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 65, 71]
#                                          星期一  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
#
#                                        星期二  \
# 0  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
# 2  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
#
#                                        星期三  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期四  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期五
# 0                                 [不在學校],,
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# [2, 5, 8]
# [12, 15, 8]
# [22, 25, 28]
# [32, 35, 28]
# [39, 35, 28]
#                    星期一                                      星期二  \
# 0  [EE綜合教學大樓],[0-5分鐘],                          [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2   [S資訊管理大樓],[0-5分鐘],                       [S資訊管理大樓],[0-5分鐘],
#
#                   星期三                  星期四                  星期五
# 0   [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],             [不在學校],,
# 1  [S資訊管理大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
# 2   [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# [2, 6, 12]
# [19, 25, 31]
# [37, 41, 47]
# [54, 60, 66]
# [73, 77, 81]
#                                          星期一  \
# 0                            [不在學校],,[不在學校],
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2    [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                          星期二  \
# 0          [體育一館],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                           [不在學校],,[不在學校],,
#
#                                        星期三  \
# 0                          [不在學校],,[不在學校],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                          星期四                     星期五
# 0        [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [EE綜合教學大樓],,[S資訊管理大樓],
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],         [不在學校],,[不在學校],
# 2     [室外籃球場],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],        [不在學校],,[不在學校],,
# [2, 8, 14]
# [20, 24, 29]
# [35, 41, 47]
# [53, 57, 63]
# [69, 73, 78]
#                                           星期一                  星期二  \
# 0  [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],  [EE綜合教學大樓],,[不在學校],
# 1               [S資訊管理大樓],[10-15分鐘],,[不在學校],,     [不在學校],,[不在學校],,
# 2                            [不在學校],,[不在學校],,     [不在學校],,[不在學校],,
#
#                                         星期三                             星期四  \
# 0  [S資訊管理大樓],[10-15分鐘],,[AA科技大樓],[10-15分鐘],           [AA科技大樓],,[CC資訊網路大樓],
# 1              [AA科技大樓],[10-15分鐘],,[不在學校],,  [CC資訊網路大樓],[10-15分鐘],,[不在學校],,
# 2                          [不在學校],,[不在學校],,                [不在學校],,[不在學校],,
#
#                      星期五
# 0  [AA科技大樓],,[EE綜合教學大樓],
# 1    [S資訊管理大樓],,[不在學校],,
# 2      [不在學校],,[不在學校],,,
# [2, 8, 14]
# [21, 27, 33]
# [40, 46, 52]
# [59, 65, 71]
# [78, 84, 90]
#                                          星期一  \
# 0    [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2    [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                          星期二  \
# 0          [體育二館],[5-10分鐘],,[體育二館],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                        星期三  \
# 0    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                          星期四                星期五
# 0      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  [不在學校],,,[不在學校],,
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  [不在學校],,,[不在學校],,
# 2                          [不在學校],,,[不在學校],,  [不在學校],,,[不在學校],,
# [2, 5, 0]
# [9, 12, 0]
# [16, 19, 0]
# [23, 19, 0]
# [23, 19, 0]
#                   星期一                   星期二                 星期三  \
# 0  [AA科技大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1   [AA科技大樓],[0-5分鐘],     [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2             x,x,x,x               x,x,x,x             x,x,x,x
#
#                     星期四                   星期五
# 0  [EE綜合教學大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],
# 1    [S資訊管理大樓],[0-5分鐘],    [S資訊管理大樓],[0-5分鐘],
# 2               x,x,x,x               x,x,x,x
# [2, 5, 8]
# [13, 16, 19]
# [24, 27, 30]
# [35, 38, 41]
# [46, 48, 51]
#                    星期一                  星期二                 星期三  \
# 0   [AA科技大樓],[5-10分鐘],  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2      [不在學校],,[不在學校],      [不在學校],,[不在學校],     [不在學校],,[不在學校],
#
#                    星期四                 星期五
# 0  [EE綜合教學大樓],[0-5分鐘],             [不在學校],
# 1  [EE綜合教學大樓],[0-5分鐘],  [AA科技大樓],[5-10分鐘],
# 2      [不在學校],,[不在學校],    [不在學校],,[不在學校],,
# [2, 5, 11]
# [15, 18, 21]
# [24, 27, 30]
# [34, 37, 39]
# [42, 44, 46]
#                                        星期一                 星期二  \
# 0                                 [不在學校],,  [AA科技大樓],[5-10分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],
# 2                      [CC資訊網路大樓],[0-5分鐘],             [不在學校],
#
#                   星期三                   星期四       星期五
# 0   [AA科技大樓],[0-5分鐘],  [EE綜合教學大樓],[5-10分鐘],   [不在學校],
# 1  [S資訊管理大樓],[0-5分鐘],               [不在學校],   [不在學校],
# 2  [S資訊管理大樓],[0-5分鐘],               [不在學校],  [不在學校],,
# [2, 5, 8]
# [12, 15, 18]
# [22, 25, 28]
# [32, 35, 38]
# [42, 44, 47]
#                    星期一                星期二                 星期三  \
# 0  [CC資訊網路大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2   [S資訊管理大樓],[0-5分鐘],           [不在學校],,            [不在學校],,
#
#                    星期四        星期五
# 0  [EE綜合教學大樓],[0-5分鐘],    [不在學校],
# 1  [EE綜合教學大樓],[0-5分鐘],   [不在學校],,
# 2             [不在學校],,  [不在學校],,,
# ...
# 1                         [AA科技大樓],[0-5分鐘],
# 2                                   [不在學校],
# 0                                   x,x,x,x
# 1                         [AA科技大樓],[0-5分鐘],
# 2                                   [不在學校],
# 0              [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1                        [AA科技大樓],[5-10分鐘],
# 2                                   [不在學校],
# 0    [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                           [不在學校],,[不在學校],
# 0                         [AA科技大樓],[0-5分鐘],
# 1                         [AA科技大樓],[0-5分鐘],
# 2                                   x,x,x,x
# 0                         [AA科技大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                                   [不在學校],
# 0                         [AA科技大樓],[0-5分鐘],
# 1                                   x,x,x,x
# 2                                   x,x,x,x
# 0                        [S資訊管理大樓],[0-5分鐘],
# 1        [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                                   x,x,x,x
# 0                           [體育一館],[0-5分鐘],
# 1                           [體育一館],[0-5分鐘],
# 2                                   x,x,x,x
# 0                        [S資訊管理大樓],[0-5分鐘],
# 1                         [AA科技大樓],[0-5分鐘],
# 2                                   [不在學校],
#
#                                         星期三  \
# 0                        [AA科技大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                                   x,x,x,x
# 0   [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1   [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2             [Q行政大樓OR圖書館],[0-5分鐘],,[不在學校],
# 0    [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 0                         [M設計大樓],[5-10分鐘],
# 1                         [M設計大樓],[5-10分鐘],
# 2                                   [不在學校],
# 0                           [不在學校],,[不在學校],
# 1       [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2     [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 0     [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                   [學校宿舍],[0-5分鐘],,[學校宿舍],
# 2                           [學校宿舍],[0-5分鐘],
# 0                          [M設計大樓],[0-5分鐘],
# 1                          [M設計大樓],[0-5分鐘],
# 2                                  [不在學校],,
# 0         [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 1         [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 2         [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 0                       [EE綜合教學大樓],[0-5分鐘],
# 1                                   [不在學校],
# 2                                   [不在學校],
# 0                      [S資訊管理大樓],[5-10分鐘],,
# 1                        [S資訊管理大樓],[0-5分鐘],
# 2                                   [不在學校],
# ..                                      ...
# 0                      [EE綜合教學大樓],[5-10分鐘],
# 1                                   [不在學校],
# 2                                   [不在學校],
# 0                       [EE綜合教學大樓],[0-5分鐘],
# 1                        [S資訊管理大樓],[0-5分鐘],
# 2                                   [不在學校],
# 0              [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1                        [AA科技大樓],[5-10分鐘],
# 2                                   [不在學校],
# 0   [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                           [不在學校],,[不在學校],
# 0    [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1                        [S資訊管理大樓],[0-5分鐘],
# 2                                   x,x,x,x
# 0                         [AA科技大樓],[0-5分鐘],
# 1           [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 2                                   [不在學校],
# 0                       [S資訊管理大樓],[5-10分鐘],
# 1                                   x,x,x,x
# 2                                   x,x,x,x
# 0                        [S資訊管理大樓],[0-5分鐘],
# 1        [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                                   x,x,x,x
# 0                           [體育一館],[0-5分鐘],
# 1                          [M設計大樓],[0-5分鐘],
# 2                          [M設計大樓],[0-5分鐘],
# 0                      [EE綜合教學大樓],[5-10分鐘],
# 1                                   [不在學校],
# 2                                   [不在學校],
#
#                                           星期二  \
# 0                          [BB社科大樓],[5-10分鐘],
# 1                          [AA科技大樓],[5-10分鐘],
# 2                                     x,x,x,x
# 0     [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1            [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 2                             [不在學校],,[不在學校],
# 0      [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1     [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2     [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 0                            [M設計大樓],[0-5分鐘],
# 1                           [M設計大樓],[5-10分鐘],
# 2                             [體育一館],[0-5分鐘],
# 0   [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 1             [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             [不在學校],,[不在學校],
# 0       [P觀光語文大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# 1                     [學校宿舍],[0-5分鐘],,[學校宿舍],
# 2                             [學校宿舍],[0-5分鐘],
# 0                            [M設計大樓],[0-5分鐘],
# 1                            [M設計大樓],[0-5分鐘],
# 2                            [M設計大樓],[0-5分鐘],
# 0           [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 1           [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 2           [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 0                         [EE綜合教學大樓],[0-5分鐘],
# 1                         [EE綜合教學大樓],[0-5分鐘],
# 2                                     [不在學校],
# 0                        [S資訊管理大樓],[5-10分鐘],,
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     [不在學校],
# ..                                        ...
# 0                        [EE綜合教學大樓],[5-10分鐘],
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     [不在學校],
# 0                                     x,x,x,x
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     [不在學校],
# 0                [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1                          [AA科技大樓],[5-10分鐘],
# 2                                     [不在學校],
# 0      [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                          [AA科技大樓],[5-10分鐘],
# 2                             [不在學校],,[不在學校],
# 0                           [AA科技大樓],[0-5分鐘],
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     x,x,x,x
# 0                           [AA科技大樓],[0-5分鐘],
# 1             [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 2                                     [不在學校],
# 0                           [AA科技大樓],[0-5分鐘],
# 1                                     x,x,x,x
# 2                                     x,x,x,x
# 0                          [S資訊管理大樓],[0-5分鐘],
# 1          [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                                     x,x,x,x
# 0                          [S資訊管理大樓],[0-5分鐘],
# 1                            [M設計大樓],[0-5分鐘],
# 2                            [M設計大樓],[0-5分鐘],
# 0      [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     [不在學校],
#
#                                             星期五  \
# 0                            [AA科技大樓],[5-10分鐘],
# 1                           [AA科技大樓],[5-10分鐘],,
# 2                                       x,x,x,x
# 0   [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 1           [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# 2                              [不在學校],,[不在學校],,
# 0        [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1       [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2       [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 0                                       [不在學校],
# 1                                       [不在學校],
# 2                                      [不在學校],,
# 0                                       [不在學校],
# 1                                       [不在學校],
# 2                              [不在學校],,[不在學校],,
# 0                               [學校宿舍],[0-5分鐘],
# 1                       [學校宿舍],[0-5分鐘],,[學校宿舍],
# 2                 [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# 0                                      [不在學校],,
# 1                                      [不在學校],,
# 2                                     [不在學校],,,
# 0                     [不在學校],,,[M設計大樓],[0-5分鐘],
# 1                     [M設計大樓],[0-5分鐘],,[不在學校],,
# 2                             [不在學校],,,[不在學校],,
# 0                           [EE綜合教學大樓],[0-5分鐘],
# 1                                       [不在學校],
# 2                                      [不在學校],,
# 0   [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# 1                            [S資訊管理大樓],[0-5分鐘],
# 2                                      [不在學校],,
# ..                                          ...
# 0                            [S資訊管理大樓],[0-5分鐘],
# 1                                       [不在學校],
# 2                                       [不在學校],
# 0                            [S資訊管理大樓],[0-5分鐘],
# 1                            [S資訊管理大樓],[0-5分鐘],
# 2                                       [不在學校],
# 0                  [不在學校],,,[S資訊管理大樓],[5-10分鐘],
# 1                            [AA科技大樓],[5-10分鐘],
# 2                                      [不在學校],,
# 0       [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                           [S資訊管理大樓],[5-10分鐘],
# 2                              [不在學校],,[不在學校],,
# 0                            [AA科技大樓],[0-5分鐘],,
# 1                            [S資訊管理大樓],[0-5分鐘],
# 2                                       x,x,x,x
# 0                             [AA科技大樓],[0-5分鐘],
# 1       [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                                      [不在學校],,
# 0                             [AA科技大樓],[0-5分鐘],
# 1                                       x,x,x,x
# 2                                       x,x,x,x
# 0                            [S資訊管理大樓],[0-5分鐘],
# 1            [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                                       x,x,x,x
# 0                            [S資訊管理大樓],[0-5分鐘],
# 1                              [體育一館],[0-5分鐘],,
# 2                              [M設計大樓],[0-5分鐘],
# 0                            [S資訊管理大樓],[0-5分鐘],
# 1                                       [不在學校],
# 2                                      [不在學校],,
#
#                                             星期四 資訊學院
# 0                            [AA科技大樓],[5-10分鐘],  NaN
# 1                           [S資訊管理大樓],[5-10分鐘],  NaN
# 2                                       x,x,x,x  NaN
# 0   [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],  NaN
# 1            [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  NaN
# 2                               [不在學校],,[不在學校],  NaN
# 0        [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  NaN
# 1       [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  NaN
# 2       [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  NaN
# 0                                       [不在學校],  NaN
# 1                                       [不在學校],  NaN
# 2                                       [不在學校],  NaN
# 0     [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],  NaN
# 1         [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  NaN
# 2                               [不在學校],,[不在學校],  NaN
# 0                               [學校宿舍],[0-5分鐘],  NaN
# 1                       [學校宿舍],[0-5分鐘],,[學校宿舍],  NaN
# 2                 [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],  NaN
# 0                              [M設計大樓],[0-5分鐘],  NaN
# 1                              [M設計大樓],[0-5分鐘],  NaN
# 2                                      [不在學校],,  NaN
# 0             [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  NaN
# 1             [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  NaN
# 2             [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  NaN
# 0                           [EE綜合教學大樓],[0-5分鐘],  NaN
# 1                           [EE綜合教學大樓],[0-5分鐘],  NaN
# 2                                       [不在學校],  NaN
# 0                            [M設計大樓],[5-10分鐘],,  NaN
# 1                            [S資訊管理大樓],[0-5分鐘],  NaN
# 2                                       [不在學校],  NaN
# ..                                          ...  ...
# 0                            [S資訊管理大樓],[0-5分鐘],  NaN
# 1                                       [不在學校],  NaN
# 2                                       [不在學校],  NaN
# 0                           [EE綜合教學大樓],[0-5分鐘],  NaN
# 1                            [S資訊管理大樓],[0-5分鐘],  NaN
# 2                                       [不在學校],  NaN
# 0                  [不在學校],,,[S資訊管理大樓],[5-10分鐘],  NaN
# 1                            [AA科技大樓],[5-10分鐘],  NaN
# 2                                       [不在學校],  NaN
# 0       [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  NaN
# 1                           [S資訊管理大樓],[5-10分鐘],  NaN
# 2                               [不在學校],,[不在學校],  NaN
# 0        [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],  NaN
# 1                            [S資訊管理大樓],[0-5分鐘],  NaN
# 2                                       x,x,x,x  NaN
# 0                             [AA科技大樓],[0-5分鐘],  NaN
# 1       [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],  NaN
# 2                                       [不在學校],  NaN
# 0                           [S資訊管理大樓],[5-10分鐘],  NaN
# 1                                       x,x,x,x  NaN
# 2                                       x,x,x,x  NaN
# 0                            [S資訊管理大樓],[0-5分鐘],  NaN
# 1            [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  NaN
# 2                                       x,x,x,x  NaN
# 0                            [S資訊管理大樓],[0-5分鐘],  NaN
# 1                               [體育一館],[0-5分鐘],  NaN
# 2                              [M設計大樓],[0-5分鐘],  NaN
# 0                            [S資訊管理大樓],[0-5分鐘],   上午
# 1                                       [不在學校],   下午
# 2                                       [不在學校],   晚上
#
# [387 rows x 6 columns]
# [0, 0, 0, 0, 0]
# ['資訊學院', '星期一', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期二', '上午', '[BB社科大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '星期三', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期四', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期五', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '', '早餐', '二餐(包含全家)', '幾點', '8-9時', '等候時間', '20-30分鐘\n']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-40-e2cc8f773dcf> in <module>()
#     111 print(daytemp)
#     112 print(ntext)
# --> 113 df1.to_csv('122.csv',encoding='big5')
#     114
#     115
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: '122.csv'

# %%
import pandas as pd
import csv
import numpy as np



df = pd.DataFrame( columns=['星期一','星期二','星期三','星期四','星期五','major'])
print(df)

ntext=[]
text=[]
daytemp=[0,0,0,0,0]
timetemp=[0,0,0]

df1 = pd.DataFrame()
txttemp=[]
A=''
B=''
C=''
f = open('final3.txt', "r",encoding='big5')
for line in f:
    text.append(line)
for co in range(len(text)):
    ntext=text[co].split(',')
    for w in range(len(ntext)):
        if '星期一' in ntext[w]:
            daytemp[0]=w
        elif '星期二' in ntext[w]:
             daytemp[1]=w
        elif '星期三' in ntext[w]:
            daytemp[2]=w
        elif '星期四' in ntext[w]:
             daytemp[3]=w
        elif '星期五' in ntext[w]:
             daytemp[4]=w
    
    for w in range (0,len(daytemp)):
        if daytemp[w]!=0:
            for ww in range(daytemp[w],daytemp[w]+15) :
                if ww == len(ntext):
                      break
                if w == len(daytemp)-1:
                      pass
                elif ww == daytemp[w+1]:
                      break   
                if '上午' in ntext[ww]:
                      timetemp[0]=ww
                if '下午' in ntext[ww]:
                      timetemp[1]=ww
                if '晚上' in ntext[ww]:
                      timetemp[2]=ww
                  #先找禮拜一的
            print('timetemp')
            print(timetemp)
        if daytemp[w]==0:
            A='x,x,x,x'
            B='x,x,x,x'
            C='x,x,x,x'
        if timetemp[0]==0:
            A='x,x,x,x'
        if timetemp[1]==0:
            B='x,x,x,x'
        if timetemp[2]==0:
            C='x,x,x,x' 
        if timetemp[0]==0 and timetemp[1]==0 and timetemp[2]==0:
            break
        if timetemp[0]>0 and timetemp[1]>0 and timetemp[2]>0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):

                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if  '\n' in ntext[timetemp[ii]+find]or'等待時間' in ntext[timetemp[ii]+find]or'晚餐' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find]or'早餐' in ntext[timetemp[ii]+find]or'下午' in ntext[timetemp[ii]+find] or '晚上' in ntext[timetemp[ii]+find]or'星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+',' 
            df[ntext[daytemp[w]]]=[A,B,C]
        if timetemp[0]==0 or timetemp[1]==0 or timetemp[2]==0:
            for ii in range(len(timetemp)):
                if timetemp[ii]>0:
                    for find in range(1,6):
                        if ntext[timetemp[ii]+find]==len(ntext):
                            break
                        if '星期五' in ntext[timetemp[ii]+find]or'星期四' in ntext[timetemp[ii]+find]or'星期三' in ntext[timetemp[ii]+find]or'星期二' in ntext[timetemp[ii]+find]or'午餐' in ntext[timetemp[ii]+find] or  '下午' in ntext[timetemp[ii]+find] or  '晚上' in ntext[timetemp[ii]+find] or  '早餐' in ntext[timetemp[ii]+find] or  '晚餐' in ntext[timetemp[ii]+find] or  '\n' in ntext[timetemp[ii]+find] or  '等候時間' in ntext[timetemp[ii]+find]:
                            break
                        if '上午' in ntext[timetemp[ii]]:    
                            A=A+ntext[timetemp[ii]+find]+','
                        elif '下午' in ntext[timetemp[ii]]:
                            B=B+ntext[timetemp[ii]+find]+','
                        else:
                            C=C+ntext[timetemp[ii]+find]+','
            df[ntext[daytemp[w]]]=[A,B,C]
            
        df['major']=[ntext[0],ntext[0],ntext[0]]
        A=''
        B=''
        C=''
        
    daytemp=[0,0,0,0,0]
    timetemp=[0,0,0]
    print(df)
    
    df = pd.concat([df1,df],axis=0)
    df1=df
    df=pd.DataFrame()
    
df.head

print(df1)

print(daytemp)
print(ntext)
df1.to_csv('122.csv',encoding='big5')
# Out:
# Empty DataFrame
# Columns: [星期一, 星期二, 星期三, 星期四, 星期五, major]
# Index: []
# timetemp
# [2, 5, 8]
# timetemp
# [11, 17, 20]
# timetemp
# [23, 26, 28]
# timetemp
# [31, 34, 36]
# timetemp
# [39, 42, 44]
#                   星期一                                     星期二  \
# 0  [S資訊管理大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],                      [S資訊管理大樓],[0-5分鐘],
# 2             [不在學校],                                 [不在學校],
#
#                     星期三                 星期四                 星期五 major
# 0  [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],  資訊學院
# 1               [不在學校],             [不在學校],             [不在學校],  資訊學院
# 2               [不在學校],             [不在學校],            [不在學校],,  資訊學院
# timetemp
# [2, 5, 0]
# timetemp
# [9, 12, 15]
# timetemp
# [19, 22, 25]
# timetemp
# [29, 32, 25]
# timetemp
# [36, 39, 25]
#                星期一 major                 星期二               星期三  \
# 0  [體育一館],[0-5分鐘],  資訊學院  [S資訊管理大樓],[0-5分鐘],   [體育一館],[0-5分鐘],
# 1  [體育一館],[0-5分鐘],  資訊學院    [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],
# 2          x,x,x,x  資訊學院    [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1     [體育一館],[0-5分鐘],    [體育一館],[0-5分鐘],,
# 2    [M設計大樓],[0-5分鐘],    [M設計大樓],[0-5分鐘],
# timetemp
# [2, 5, 0]
# timetemp
# [12, 15, 0]
# timetemp
# [22, 25, 0]
# timetemp
# [32, 35, 0]
# timetemp
# [42, 45, 0]
#                                   星期一 major  \
# 0                  [S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  資訊學院
# 2                             x,x,x,x  資訊學院
#
#                                   星期二                                 星期三  \
# 0                  [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             x,x,x,x                             x,x,x,x
#
#                                   星期四                                 星期五
# 0                  [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                             x,x,x,x                             x,x,x,x
# timetemp
# [2, 0, 0]
# timetemp
# [2, 0, 0]
# timetemp
# [10, 0, 0]
# timetemp
# [10, 0, 0]
# timetemp
# [18, 0, 0]
#                  星期一 major                星期二                  星期三  \
# 0  [AA科技大樓],[0-5分鐘],  資訊學院  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1            x,x,x,x  資訊學院            x,x,x,x              x,x,x,x
# 2            x,x,x,x  資訊學院            x,x,x,x              x,x,x,x
#
#                    星期四                星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[0-5分鐘],
# 1              x,x,x,x            x,x,x,x
# 2              x,x,x,x            x,x,x,x
# timetemp
# [2, 5, 11]
# timetemp
# [14, 17, 23]
# timetemp
# [26, 29, 35]
# timetemp
# [38, 41, 47]
# timetemp
# [50, 53, 59]
#                                        星期一 major  \
# 0                        [AA科技大樓],[0-5分鐘],  資訊學院
# 1  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],  資訊學院
# 2                                  [不在學校],  資訊學院
#
#                                星期二                              星期三  \
# 0                [AA科技大樓],[0-5分鐘],                [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 2                          [不在學校],                          [不在學校],
#
#                                        星期四  \
# 0                        [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                                  [不在學校],
#
#                                        星期五
# 0                        [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 2                                 [不在學校],,
# timetemp
# [2, 5, 0]
# timetemp
# [9, 12, 0]
# timetemp
# [16, 22, 0]
# timetemp
# [16, 22, 0]
# timetemp
# [27, 22, 0]
#                  星期一 major                 星期二  \
# 0  [AA科技大樓],[0-5分鐘],  資訊學院   [AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],  資訊學院  [S資訊管理大樓],[0-5分鐘],
# 2            x,x,x,x  資訊學院             x,x,x,x
#
#                                       星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1                      [S資訊管理大樓],[0-5分鐘],
# 2                                 x,x,x,x
#
#                                       星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,
# 1                      [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2                                 x,x,x,x             x,x,x,x
# timetemp
# [2, 8, 11]
# timetemp
# [16, 22, 25]
# timetemp
# [30, 36, 39]
# timetemp
# [30, 36, 44]
# timetemp
# [30, 36, 49]
#                                       星期一 major  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
# 1                     [S資訊管理大樓],[5-10分鐘],  資訊學院
# 2                         [不在學校],,[不在學校],  資訊學院
#
#                                       星期二  \
# 0  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [AA科技大樓],[5-10分鐘],
# 2                         [不在學校],,[不在學校],
#
#                                        星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                        星期四  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                        星期五
# 0  [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                         [不在學校],,[不在學校],,
# timetemp
# [2, 8, 11]
# timetemp
# [14, 20, 23]
# timetemp
# [26, 32, 35]
# timetemp
# [38, 44, 47]
# timetemp
# [50, 56, 59]
#                              星期一 major                            星期二  \
# 0  [不在學校],x,,[S資訊管理大樓],[5-10分鐘],  資訊學院  [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# 1             [AA科技大樓],[5-10分鐘],  資訊學院             [AA科技大樓],[5-10分鐘],
# 2                        [不在學校],  資訊學院                        [不在學校],
#
#                              星期三                            星期四  \
# 0  [不在學校],x,,[S資訊管理大樓],[5-10分鐘],  [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# 1             [AA科技大樓],[5-10分鐘],             [AA科技大樓],[5-10分鐘],
# 2                        [不在學校],                        [不在學校],
#
#                              星期五
# 0  [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# 1             [AA科技大樓],[5-10分鐘],
# 2                       [不在學校],,
# timetemp
# [0, 2, 5]
# timetemp
# [0, 8, 11]
# timetemp
# [14, 8, 17]
# timetemp
# [14, 8, 17]
# timetemp
# [23, 8, 26]
#                  星期一 major                 星期二                  星期三  \
# 0            x,x,x,x  資訊學院             x,x,x,x  [EE綜合教學大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],  資訊學院  [S資訊管理大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2            [不在學校],  資訊學院             [不在學校],              [不在學校],
#
#                    星期四                 星期五
# 0  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2              [不在學校],             [不在學校],
# timetemp
# [2, 5, 8]
# timetemp
# [11, 14, 17]
# timetemp
# [20, 23, 25]
# timetemp
# [28, 31, 33]
# timetemp
# [28, 31, 33]
#                   星期一 major                   星期二                   星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],
# 1   [AA科技大樓],[0-5分鐘],  資訊學院    [S資訊管理大樓],[0-5分鐘],               [不在學校],
# 2             [不在學校],  資訊學院               [不在學校],               [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],             [不在學校],
# 2             [不在學校],             [不在學校],
# timetemp
# [2, 5, 8]
# timetemp
# [11, 14, 17]
# timetemp
# [20, 23, 25]
# timetemp
# [28, 31, 33]
# timetemp
# [28, 31, 33]
#                   星期一 major                   星期二                   星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[5-10分鐘],  [EE綜合教學大樓],[5-10分鐘],
# 1   [AA科技大樓],[0-5分鐘],  資訊學院    [S資訊管理大樓],[0-5分鐘],               [不在學校],
# 2             [不在學校],  資訊學院               [不在學校],               [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],             [不在學校],
# 2             [不在學校],             [不在學校],
# timetemp
# [2, 8, 14]
# timetemp
# [20, 26, 32]
# timetemp
# [38, 44, 50]
# timetemp
# [56, 62, 68]
# timetemp
# [74, 80, 86]
#                                     星期一 major  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1               [二餐],[0-5分鐘],,[不在學校],x,  資訊學院
# 2             [不在學校],,[AA科技大樓],[0-5分鐘],  資訊學院
#
#                                     星期二                                   星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1               [二餐],[0-5分鐘],,[不在學校],x,               [二餐],[0-5分鐘],,[不在學校],x,
# 2             [不在學校],,[AA科技大樓],[0-5分鐘],             [不在學校],,[AA科技大樓],[0-5分鐘],
#
#                                     星期四                                   星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1               [二餐],[0-5分鐘],,[不在學校],x,               [二餐],[0-5分鐘],,[不在學校],x,
# 2             [不在學校],,[AA科技大樓],[0-5分鐘],            [不在學校],,[AA科技大樓],[0-5分鐘],,
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [36, 40, 44]
# timetemp
# [49, 55, 60]
# timetemp
# [65, 69, 73]
#                                       星期一 major  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 2                         [不在學校],,[不在學校],  資訊學院
#
#                                       星期二              星期三  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],
# 2                         [不在學校],,[不在學校],  [不在學校],,[不在學校],
#
#                                      星期四               星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],   [不在學校],,[不在學校],
# 1            [S資訊管理大樓],[5-10分鐘],,[不在學校],   [不在學校],,[不在學校],
# 2                        [不在學校],,[不在學校],  [不在學校],,[不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [17, 23, 29]
# timetemp
# [36, 23, 43]
# timetemp
# [47, 23, 43]
# timetemp
# [47, 23, 43]
#                                    星期一 major  \
# 0  [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1  [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],  資訊學院
# 2                                   x,  資訊學院
#
#                                          星期二  \
# 0    [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[10-15分鐘],,[EE綜合教學大樓],[10-15分鐘],
#
#                                          星期三  \
# 0  [S資訊管理大樓],[10-15分鐘],,[P觀光語文大樓],[10-15分鐘],
# 1      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                        [P觀光語文大樓],[5-10分鐘],
#
#                                      星期四  \
# 0                                     x,
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [P觀光語文大樓],[5-10分鐘],
#
#                                      星期五
# 0                                     x,
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [P觀光語文大樓],[5-10分鐘],
# timetemp
# [2, 4, 9]
# timetemp
# [13, 16, 21]
# timetemp
# [24, 27, 32]
# timetemp
# [36, 39, 42]
# timetemp
# [45, 47, 49]
#                       星期一 major                     星期二  \
# 0                 [不在學校],  資訊學院         [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,x,  資訊學院  [EE綜合教學大樓],[0-5分鐘],,x,
# 2      [S資訊管理大樓],[0-5分鐘],  資訊學院                 [不在學校],
#
#                      星期三                  星期四       星期五
# 0      [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],   [不在學校],
# 1  [S資訊管理大樓],[0-5分鐘],,x,  [CC資訊網路大樓],[0-5分鐘],   [不在學校],
# 2      [AA科技大樓],[0-5分鐘],              [不在學校],  [不在學校],,
# timetemp
# [0, 2, 5]
# timetemp
# [0, 9, 15]
# timetemp
# [19, 22, 15]
# timetemp
# [26, 29, 15]
# timetemp
# [33, 29, 15]
#                      星期一 major                                         星期二  \
# 0                x,x,x,x  資訊學院                                     x,x,x,x
# 1    [S資訊管理大樓],[5-10分鐘],  資訊學院  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[10-15分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  資訊學院                         [AA科技大樓],[10-15分鐘],
#
#                    星期三                  星期四                   星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,
# 1  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],
# 2  [AA科技大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],   [AA科技大樓],[10-15分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [20, 26, 32]
# timetemp
# [37, 43, 49]
# timetemp
# [55, 61, 67]
# timetemp
# [72, 78, 83]
#                                         星期一 major  \
# 0         [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],  資訊學院
# 1  [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
# 2               [S資訊管理大樓],[5-10分鐘],,[不在學校],  資訊學院
#
#                                        星期二  \
# 0     [室外籃球場],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                       星期三  \
# 0   [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2              [AA科技大樓],[5-10分鐘],,[不在學校],
#
#                                          星期四                            星期五
# 0        [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],,[不在學校],x,
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],              [不在學校],x,,[不在學校],
# 2                            [不在學校],,[不在學校],               [不在學校],,[不在學校],,
# timetemp
# [2, 7, 13]
# timetemp
# [20, 25, 31]
# timetemp
# [38, 44, 50]
# timetemp
# [57, 62, 68]
# timetemp
# [75, 80, 86]
#                                     星期一 major  \
# 0                  [AA科技大樓],[0-5分鐘],,x,  資訊學院
# 1  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],  資訊學院
# 2         [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,  資訊學院
#
#                                      星期二  \
# 0                 [EE綜合教學大樓],[0-5分鐘],,x,
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [不在學校],x,,[不在學校],x,
#
#                                     星期三  \
# 0        [M設計大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# 2                   [不在學校],x,,[不在學校],x,
#
#                                      星期四                                   星期五
# 0                  [P觀光語文大樓],[0-5分鐘],,x,                 [S資訊管理大樓],[0-5分鐘],,x,
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# 2                    [不在學校],x,,[不在學校],x,                   [不在學校],x,,[不在學校],x,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 18]
# timetemp
# [22, 25, 18]
# timetemp
# [29, 32, 18]
# timetemp
# [36, 32, 18]
#                     星期一 major                 星期二                 星期三  \
# 0    [AA科技大樓],[5-10分鐘],  資訊學院    [體育一館],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
#
#                   星期四                     星期五
# 0  [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],x,,
# 1  [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# timetemp
# [2, 5, 8]
# timetemp
# [11, 14, 20]
# timetemp
# [23, 26, 29]
# timetemp
# [32, 35, 38]
# timetemp
# [41, 44, 46]
#                    星期一 major                                      星期二  \
# 0   [AA科技大樓],[5-10分鐘],  資訊學院                          [體育一館],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],  資訊學院  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2              [不在學校],  資訊學院                                  [不在學校],
#
#                    星期三                  星期四                  星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],              [不在學校],
# 2              [不在學校],              [不在學校],             [不在學校],,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 14, 17]
# timetemp
# [20, 23, 26]
# timetemp
# [30, 33, 36]
# timetemp
# [39, 42, 44]
#                    星期一 major                  星期二                  星期三  \
# 0            [不在學校],x,  資訊學院                   x,  [EE綜合教學大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  資訊學院  [CC資訊網路大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  資訊學院              [不在學校],  [CC資訊網路大樓],[0-5分鐘],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],            [不在學校],,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 8]
# timetemp
# [12, 22, 8]
# timetemp
# [26, 29, 8]
# timetemp
# [33, 29, 8]
#                      星期一 major                                       星期二  \
# 0     [AA科技大樓],[5-10分鐘],  資訊學院                           [體育一館],[0-5分鐘],
# 1     [S資訊管理大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  資訊學院                     [CC資訊網路大樓],[10-15分鐘],
#
#                      星期三                    星期四                    星期五
# 0        [體育一館],[0-5分鐘],    [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],,
# 1    [S資訊管理大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  [CC資訊網路大樓],[10-15分鐘],  [CC資訊網路大樓],[10-15分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                          星期一 major  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],  資訊學院
# 1     [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  資訊學院
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
#
#                                       星期二  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                    [不在學校],x,,[不在學校],x,
#
#                                        星期四  \
# 0   [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                      [不在學校],x,,[不在學校],x,
#
#                                       星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                     [不在學校],x,,[不在學校],x,
# 2                     [不在學校],x,,[不在學校],x,
# timetemp
# [2, 5, 11]
# timetemp
# [15, 21, 27]
# timetemp
# [31, 37, 27]
# timetemp
# [41, 47, 27]
# timetemp
# [51, 47, 27]
#                                       星期一 major  \
# 0                      [S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  資訊學院
# 2                       [AA科技大樓],[0-5分鐘],  資訊學院
#
#                                      星期二  \
# 0      [體育一館],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                     [S資訊管理大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],
# 1                      [AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                      [AA科技大樓],[0-5分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [34, 40, 46]
# timetemp
# [49, 55, 61]
# timetemp
# [64, 70, 76]
#                                      星期一 major  \
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 2                  [CC資訊網路大樓],[0-5分鐘],x,  資訊學院
#
#                                      星期二  \
# 0  [S資訊管理大樓],[10-15分鐘],,[體育一館],[5-10分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                                [不在學校],
#
#                                      星期三  \
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                                [不在學校],
#
#                                      星期四  \
# 0  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                                     x,
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1           [S資訊管理大樓],[0-5分鐘],,[不在學校],x,
# 2                               [不在學校],,
# timetemp
# [2, 5, 11]
# timetemp
# C:\Users\schoolpc\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:108: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# [15, 18, 21]
# timetemp
# [25, 28, 31]
# timetemp
# [34, 37, 40]
# timetemp
# [46, 49, 52]
#                                       星期一 major                星期二  \
# 0                               [不在學校],x,  資訊學院    [體育一館],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  資訊學院  [AA科技大樓],[0-5分鐘],
# 2                       [AA科技大樓],[0-5分鐘],  資訊學院  [AA科技大樓],[0-5分鐘],
#
#                   星期三                        星期四                星期五
# 0  [S資訊管理大樓],[0-5分鐘],         [S資訊管理大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],         [S資訊管理大樓],[0-5分鐘],          [不在學校],x,
# 2             [不在學校],  [不在學校],,[室外籃球場],[20分鐘以上],           [不在學校],,
# timetemp
# [2, 7, 11]
# timetemp
# [15, 20, 11]
# timetemp
# [25, 30, 34]
# timetemp
# [38, 43, 34]
# timetemp
# [48, 53, 34]
#                       星期一 major                     星期二  \
# 0  [S資訊管理大樓],[5-10分鐘],,x,  資訊學院    [體育一館],[10-15分鐘],,x,
# 1  [CC資訊網路大樓],[5-10分鐘],x,  資訊學院  [EE綜合教學大樓],[5-10分鐘],x,
# 2   [CC資訊網路大樓],[10-15分鐘],  資訊學院   [CC資訊網路大樓],[10-15分鐘],
#
#                        星期三                     星期四                      星期五
# 0  [S資訊管理大樓],[10-15分鐘],,x,  [AA科技大樓],[10-15分鐘],,x,  [S資訊管理大樓],[10-15分鐘],,x,
# 1     [AA科技大樓],[5-10分鐘],x,    [AA科技大樓],[5-10分鐘],x,    [AA科技大樓],[5-10分鐘],x,,
# 2      [AA科技大樓],[10-15分鐘],     [AA科技大樓],[10-15分鐘],      [AA科技大樓],[10-15分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 85, 88]
#                                          星期一 major  \
# 0      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  資訊學院
# 1     [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  資訊學院
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
#
#                                          星期二  \
# 0           [體育一館],[0-5分鐘],,[體育一館],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 2      [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                        星期三  \
# 0    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                      [不在學校],x,,[不在學校],x,
#
#                                        星期四  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1   [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                      [不在學校],x,,[不在學校],x,
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                                [不在學校],x,
# 2                      [不在學校],x,,[不在學校],x,
# timetemp
# [2, 5, 0]
# timetemp
# [12, 14, 0]
# timetemp
# [21, 24, 0]
# timetemp
# [28, 31, 0]
# timetemp
# [35, 31, 0]
#                                       星期一 major  \
# 0                      [AA科技大樓],[5-10分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  資訊學院
# 2                                 x,x,x,x  資訊學院
#
#                                       星期二                  星期三  \
# 0                                      x,  [AA科技大樓],[10-15分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2                                 x,x,x,x              x,x,x,x
#
#                     星期四                    星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],,
# 1    [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2               x,x,x,x                x,x,x,x
# timetemp
# [2, 5, 11]
# timetemp
# [17, 23, 29]
# timetemp
# [34, 40, 46]
# timetemp
# [51, 57, 63]
# timetemp
# [68, 74, 78]
#                                     星期一 major  \
# 0                    [S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 2           [CC資訊網路大樓],[0-5分鐘],,[不在學校],  資訊學院
#
#                                      星期二  \
# 0        [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                        [不在學校],,[不在學校],
# 2                       [不在學校],,[不在學校],,
# timetemp
# [2, 5, 11]
# timetemp
# [17, 23, 29]
# timetemp
# [35, 41, 47]
# timetemp
# [53, 59, 65]
# timetemp
# [71, 59, 76]
#                                     星期一 major  \
# 0                     [AA科技大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 2                     [不在學校],,[不在學校],x,  資訊學院
#
#                                    星期二                                   星期三  \
# 0    [體育一館],[0-5分鐘],,[AA科技大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                    [不在學校],,[不在學校],x,                     [不在學校],,[不在學校],x,
#
#                                     星期四                                  星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],         [S資訊管理大樓],[0-5分鐘],x,[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                     [不在學校],,[不在學校],x,                   [不在學校],,[不在學校],x,,
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [36, 42, 47]
# timetemp
# [52, 58, 63]
# timetemp
# [68, 74, 79]
#                                         星期一 major  \
# 0                       [不在學校],x,,[不在學校],x,  資訊學院
# 1  [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
# 2                           [不在學校],,[不在學校],  資訊學院
#
#                                        星期二  \
# 0                [體育一館],[0-5分鐘],,[不在學校],x,
# 1  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                       星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1             [S資訊管理大樓],[5-10分鐘],,[不在學校],
# 2                         [不在學校],,[不在學校],
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1             [AA科技大樓],[5-10分鐘],,[不在學校],
# 2                        [不在學校],,[不在學校],
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1             [EE綜合教學大樓],[5-10分鐘],,[不在學校],
# 2                         [不在學校],,[不在學校],,
# timetemp
# [2, 5, 0]
# timetemp
# [12, 14, 0]
# timetemp
# [21, 24, 0]
# timetemp
# [28, 31, 0]
# timetemp
# [35, 31, 0]
#                                       星期一 major  \
# 0                      [AA科技大樓],[5-10分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  資訊學院
# 2                                 x,x,x,x  資訊學院
#
#                                       星期二                  星期三  \
# 0                                      x,  [AA科技大樓],[10-15分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2                                 x,x,x,x              x,x,x,x
#
#                     星期四                    星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],,
# 1    [AA科技大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],
# 2               x,x,x,x                x,x,x,x
# timetemp
# [2, 4, 7]
# timetemp
# [11, 14, 20]
# timetemp
# [24, 27, 30]
# timetemp
# [33, 36, 39]
# timetemp
# [42, 45, 47]
#                    星期一 major                                     星期二  \
# 0              [不在學校],  資訊學院                         [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  資訊學院  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  資訊學院                       [AA科技大樓],[0-5分鐘],
#
#                   星期三                 星期四                 星期五
# 0   [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],             [不在學校],            [不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                        星期一 major  \
# 0      [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],  資訊學院
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
# 2    [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],  資訊學院
#
#                                          星期二  \
# 0          [體育一館],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[Q行政大樓OR圖書館],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
#
#                                       星期三  \
# 0     [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                     [不在學校],x,,[不在學校],x,
#
#                                      星期四                                   星期五
# 0    [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],                   [不在學校],x,,[不在學校],x,
# 2                    [不在學校],x,,[不在學校],x,                   [不在學校],x,,[不在學校],x,
# timetemp
# [2, 8, 12]
# timetemp
# [17, 23, 27]
# timetemp
# [32, 38, 42]
# timetemp
# [47, 53, 57]
# timetemp
# [62, 68, 72]
#                                    星期一 major  \
# 0  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1                [CC資訊網路大樓],[0-5分鐘],x,  資訊學院
# 2                 [S資訊管理大樓],[0-5分鐘],x,  資訊學院
#
#                                  星期二                                  星期三  \
# 0  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 1                [AA科技大樓],[0-5分鐘],x,                 [S資訊管理大樓],[0-5分鐘],x,
# 2                [AA科技大樓],[0-5分鐘],x,                          [不在學校],x,x,
#
#                                     星期四                                    星期五
# 0  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                   [AA科技大樓],[0-5分鐘],x,                            [不在學校],x,x,
# 2                           [不在學校],x,x,                           [不在學校],x,x,,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [58, 64, 70]
# timetemp
# [76, 82, 88]
#                                    星期一 major  \
# 0    [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  資訊學院
# 1  [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  資訊學院
# 2  [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  資訊學院
#
#                                  星期二                                 星期三  \
# 0    [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],                   [不在學校],,[不在學校],x,
#
#                                  星期四                                星期五
# 0  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 1  [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],          [不在學校],x,,[體育一館],[0-5分鐘],
# 2                  [不在學校],,[不在學校],x,                 [不在學校],,[不在學校],x,,
# timetemp
# [2, 4, 7]
# timetemp
# [11, 14, 17]
# timetemp
# [21, 24, 27]
# timetemp
# [30, 33, 36]
# timetemp
# [39, 42, 44]
#                    星期一 major                  星期二                 星期三  \
# 0              [不在學校],  資訊學院  [EE綜合教學大樓],[0-5分鐘],  [AA科技大樓],[5-10分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  資訊學院   [AA科技大樓],[5-10分鐘],             [不在學校],
#
#                   星期四                 星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],             [不在學校],
# 2             [不在學校],            [不在學校],,
# timetemp
# [2, 4, 7]
# timetemp
# [11, 14, 17]
# timetemp
# [21, 23, 25]
# timetemp
# [28, 31, 34]
# timetemp
# [37, 40, 42]
#                   星期一 major                  星期二      星期三                 星期四  \
# 0             [不在學校],  資訊學院  [EE綜合教學大樓],[0-5分鐘],  [不在學校],  [S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[0-5分鐘],  [不在學校],   [AA科技大樓],[0-5分鐘],
# 2   [AA科技大樓],[0-5分鐘],  資訊學院  [CC資訊網路大樓],[0-5分鐘],  [不在學校],             [不在學校],
#
#                   星期五
# 0  [S資訊管理大樓],[0-5分鐘],
# 1             [不在學校],
# 2            [不在學校],,
# timetemp
# [2, 8, 0]
# timetemp
# [15, 21, 0]
# timetemp
# [15, 21, 0]
# timetemp
# [29, 35, 0]
# timetemp
# [42, 35, 0]
#                                       星期一 major  \
# 0    [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],  資訊學院
# 2                                 x,x,x,x  資訊學院
#
#                                        星期二  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                                  x,x,x,x
#
#                                        星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 2                                  x,x,x,x
#
#                                     星期四                                    星期五
# 0  [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2                               x,x,x,x                                x,x,x,x
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                      星期一 major  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 2                    [不在學校],x,,[不在學校],x,  資訊學院
#
#                                      星期二  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                    [不在學校],x,,[不在學校],x,
#
#                                      星期三  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                    [不在學校],x,,[不在學校],x,
#
#                                      星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                    [不在學校],x,,[不在學校],x,
#
#                                      星期五
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 2                    [不在學校],x,,[不在學校],x,
# timetemp
# [0, 2, 5]
# timetemp
# [9, 12, 18]
# timetemp
# [22, 25, 18]
# timetemp
# [29, 32, 18]
# timetemp
# [36, 32, 18]
#                     星期一 major                                       星期二  \
# 0               x,x,x,x  資訊學院                          [體育一館],[5-10分鐘],
# 1   [S資訊管理大樓],[5-10分鐘],  資訊學院  [EE綜合教學大樓],[5-10分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  資訊學院                        [AA科技大樓],[5-10分鐘],
#
#                    星期三                  星期四                     星期五
# 0   [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],x,,
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# 2   [AA科技大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [36, 42, 48]
# timetemp
# [53, 59, 65]
# timetemp
# [70, 76, 82]
#                                        星期一 major  \
# 0             [不在學校],x,,[AA科技大樓],[5-10分鐘],  資訊學院
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
# 2                   [CC資訊網路大樓],[5-10分鐘],x,  資訊學院
#
#                                        星期二  \
# 0      [體育一館],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                    [S資訊管理大樓],[5-10分鐘],x,
#
#                                        星期三  \
# 0   [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                              [不在學校],x,x,
#
#                                        星期四  \
# 0   [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2                              [不在學校],x,x,
#
#                                       星期五
# 0   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                            [不在學校],x,x,,
# timetemp
# [2, 8, 14]
# timetemp
# [18, 24, 30]
# timetemp
# [34, 40, 46]
# timetemp
# [50, 56, 62]
# timetemp
# [66, 72, 78]
#                                     星期一 major  \
# 0   [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 2                   [CC資訊網路大樓],[0-5分鐘],  資訊學院
#
#                                        星期二                              星期三  \
# 0          [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[二餐],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],     [S資訊管理大樓],[0-5分鐘],,[不在學校],x,
# 2                        [AA科技大樓],[0-5分鐘],                        [不在學校],x,
#
#                                    星期四                          星期五
# 0     [S資訊管理大樓],[0-5分鐘],,[二餐],[0-5分鐘],  [AA科技大樓],[0-5分鐘],,[不在學校],x,
# 1  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],          [不在學校],x,,[不在學校],x,
# 2                            [不在學校],x,                   [不在學校],x,,
# timetemp
# [2, 4, 7]
# timetemp
# [11, 15, 21]
# timetemp
# [24, 28, 31]
# timetemp
# [34, 38, 41]
# timetemp
# [44, 48, 51]
#                     星期一 major                                        星期二  \
# 0               [不在學校],  資訊學院                     [EE綜合教學大樓],[5-10分鐘],x,
# 1   [S資訊管理大樓],[5-10分鐘],  資訊學院  [CC資訊網路大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  資訊學院                                    [不在學校],
#
#                       星期三                    星期四                    星期五
# 0  [EE綜合教學大樓],[5-10分鐘],x,  [S資訊管理大樓],[5-10分鐘],x,  [S資訊管理大樓],[5-10分鐘],x,
# 1     [S資訊管理大樓],[5-10分鐘],     [AA科技大樓],[5-10分鐘],              [不在學校],x,
# 2                 [不在學校],                [不在學校],               [不在學校],,
# timetemp
# [2, 7, 10]
# timetemp
# [14, 20, 23]
# timetemp
# [27, 32, 37]
# timetemp
# [40, 46, 49]
# timetemp
# [53, 59, 62]
#                               星期一 major                            星期二  \
# 0  [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],  資訊學院  [體育一館],[0-5分鐘],,[操場],[0-5分鐘],
# 1             [S資訊管理大樓],[5-10分鐘],  資訊學院            [S資訊管理大樓],[5-10分鐘],
# 2             [S資訊管理大樓],[5-10分鐘],  資訊學院            [S資訊管理大樓],[5-10分鐘],
#
#                              星期三                                      星期四  \
# 0  [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1    [不在學校],,[S資訊管理大樓],[5-10分鐘],                      [S資訊管理大樓],[5-10分鐘],
# 2                        [不在學校],                   [Q行政大樓OR圖書館],[5-10分鐘],
#
#                                        星期五
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1                      [S資訊管理大樓],[5-10分鐘],
# 2                  [Q行政大樓OR圖書館],[5-10分鐘],,
# timetemp
# [2, 7, 13]
# timetemp
# [20, 25, 31]
# timetemp
# [38, 43, 49]
# timetemp
# [56, 61, 67]
# timetemp
# [74, 79, 85]
#                              星期一 major                             星期二  \
# 0              [不在學校],,[不在學校],x,  資訊學院          x,,[S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[不在學校],x,  資訊學院  [CC資訊網路大樓],[5-10分鐘],,[不在學校],x,
# 2  [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,  資訊學院             [不在學校],x,,[不在學校],x,
#
#                             星期三                           星期四  \
# 0             [不在學校],,[不在學校],x,        x,,[S資訊管理大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],,[不在學校],x,  [AA科技大樓],[5-10分鐘],,[不在學校],x,
# 2           [不在學校],x,,[不在學校],x,           [不在學校],x,,[不在學校],x,
#
#                             星期五
# 0             [不在學校],,[不在學校],x,
# 1  [AA科技大樓],[5-10分鐘],,[不在學校],x,
# 2           [不在學校],x,,[不在學校],x,
# timetemp
# [2, 8, 11]
# timetemp
# [15, 21, 27]
# timetemp
# [31, 37, 27]
# timetemp
# [41, 47, 27]
# timetemp
# [51, 47, 27]
#                                         星期一 major  \
# 0  [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
# 1                      [CC資訊網路大樓],[5-10分鐘],  資訊學院
# 2                       [CC資訊網路大樓],[0-5分鐘],  資訊學院
#
#                                        星期二  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2                        [AA科技大樓],[0-5分鐘],
#
#                                         星期三  \
# 0  [S資訊管理大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                         [AA科技大樓],[0-5分鐘],
#
#                                       星期四                     星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],x,,
# 1                      [AA科技大樓],[5-10分鐘],      [AA科技大樓],[5-10分鐘],
# 2                       [AA科技大樓],[0-5分鐘],       [AA科技大樓],[0-5分鐘],
# timetemp
# [2, 5, 8]
# timetemp
# [11, 14, 17]
# timetemp
# [20, 23, 26]
# timetemp
# [30, 33, 36]
# timetemp
# [39, 42, 45]
#                   星期一 major                 星期二                  星期三  \
# 0     [學校宿舍],[0-5分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],      [學校宿舍],[0-5分鐘],
# 1  [S資訊管理大樓],[0-5分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],  [EE綜合教學大樓],[0-5分鐘],
# 2                  x,  資訊學院                  x,   [S資訊管理大樓],[0-5分鐘],
#
#                   星期四                星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1   [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 2                  x,                x,,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 18]
# timetemp
# [22, 25, 18]
# timetemp
# [29, 32, 18]
# timetemp
# [36, 32, 18]
#                      星期一 major                    星期二                  星期三  \
# 0  [EE綜合教學大樓],[10-15分鐘],  資訊學院  [EE綜合教學大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],
# 1   [CC資訊網路大樓],[5-10分鐘],  資訊學院   [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  資訊學院    [AA科技大樓],[10-15分鐘],  [AA科技大樓],[10-15分鐘],
#
#                     星期四                      星期五
# 0  [S資訊管理大樓],[10-15分鐘],  [S資訊管理大樓],[10-15分鐘],x,,
# 1    [AA科技大樓],[5-10分鐘],       [AA科技大樓],[5-10分鐘],
# 2   [AA科技大樓],[10-15分鐘],      [AA科技大樓],[10-15分鐘],
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 8]
# timetemp
# [19, 22, 8]
# timetemp
# [26, 29, 8]
# timetemp
# [33, 29, 8]
#                    星期一 major                  星期二                  星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],  資訊學院      [體育一館],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],  資訊學院  [CC資訊網路大樓],[0-5分鐘],   [S資訊管理大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  資訊學院  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
#
#                    星期四                  星期五
# 0   [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,
# 1    [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# 2  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
# timetemp
# [0, 2, 4]
# timetemp
# [8, 11, 14]
# timetemp
# [17, 20, 23]
# timetemp
# [26, 29, 32]
# timetemp
# [35, 29, 39]
#                      星期一 major                   星期二                  星期三  \
# 0                x,x,x,x  資訊學院      [體育一館],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1                     x,  資訊學院  [CC資訊網路大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[10-15分鐘],  資訊學院               [不在學校],              [不在學校],
#
#                   星期四                    星期五
# 0  [S資訊管理大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],x,
# 1   [AA科技大樓],[0-5分鐘],      [AA科技大樓],[0-5分鐘],
# 2             [不在學校],               [不在學校],,
# timetemp
# [2, 5, 0]
# timetemp
# [9, 12, 0]
# timetemp
# [15, 18, 0]
# timetemp
# [22, 25, 0]
# timetemp
# [29, 25, 0]
#                     星期一 major                   星期二                  星期三  \
# 0   [S資訊管理大樓],[5-10分鐘],  資訊學院  [CC資訊網路大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  資訊學院                    x,  [S資訊管理大樓],[5-10分鐘],
# 2               x,x,x,x  資訊學院               x,x,x,x              x,x,x,x
#
#                    星期四                   星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],,
# 1  [S資訊管理大樓],[5-10分鐘],   [S資訊管理大樓],[5-10分鐘],
# 2              x,x,x,x               x,x,x,x
# timetemp
# [0, 2, 5]
# timetemp
# [9, 12, 5]
# timetemp
# [16, 19, 22]
# timetemp
# [26, 29, 22]
# timetemp
# [26, 29, 22]
#                    星期一 major                  星期二                 星期三  \
# 0              x,x,x,x  資訊學院   [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  資訊學院  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],  資訊學院  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
#
#                   星期四                 星期五
# 0  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 1  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# 2  [AA科技大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],
# timetemp
# [2, 7, 10]
# timetemp
# [14, 20, 23]
# timetemp
# [27, 33, 36]
# timetemp
# [40, 46, 49]
# timetemp
# [53, 58, 61]
#                            星期一 major                                  星期二  \
# 0  [不在學校],,[EE綜合教學大樓],[0-5分鐘],  資訊學院  [體育一館],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1          [EE綜合教學大樓],[0-5分鐘],  資訊學院                   [AA科技大樓],[5-10分鐘],
# 2            [AA科技大樓],[0-5分鐘],  資訊學院                            [不在學校],x,
#
#                                      星期三  \
# 0  [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 1                    [S資訊管理大樓],[5-10分鐘],
# 2                      [AA科技大樓],[0-5分鐘],
#
#                                      星期四                星期五
# 0  [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  [不在學校],,[不在學校],x,
# 1                      [AA科技大樓],[0-5分鐘],          [不在學校],x,
# 2                              [不在學校],x,         [不在學校],x,,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 18]
# timetemp
# [22, 25, 28]
# timetemp
# [31, 34, 37]
# timetemp
# [40, 43, 46]
#                     星期一 major                 星期二                  星期三  \
# 0    [AA科技大樓],[5-10分鐘],  資訊學院     [體育一館],[0-5分鐘],   [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  資訊學院   [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2  [CC資訊網路大樓],[5-10分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],              [不在學校],
#
#                    星期四                  星期五
# 0  [S資訊管理大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 2              [不在學校],             [不在學校],,
# timetemp
# [2, 5, 0]
# timetemp
# [9, 12, 0]
# timetemp
# [16, 19, 0]
# timetemp
# [23, 26, 0]
# timetemp
# [23, 26, 0]
#                     星期一 major                   星期二                  星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],  資訊學院      [體育一館],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1   [S資訊管理大樓],[5-10分鐘],  資訊學院  [EE綜合教學大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2               x,x,x,x  資訊學院               x,x,x,x              x,x,x,x
#
#                     星期四                   星期五
# 0    [AA科技大樓],[5-10分鐘],    [AA科技大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[5-10分鐘],  [CC資訊網路大樓],[5-10分鐘],
# 2               x,x,x,x               x,x,x,x
# timetemp
# [2, 4, 6]
# timetemp
# [9, 12, 14]
# timetemp
# [17, 20, 22]
# timetemp
# [25, 28, 30]
# timetemp
# [25, 33, 35]
#        星期一 major              星期二                星期三                星期四  \
# 0  [不在學校],  資訊學院  [體育一館],[0-5分鐘],  [AA科技大樓],[0-5分鐘],  [AA科技大樓],[0-5分鐘],
# 1       x,  資訊學院          [不在學校],                 x,            [不在學校],
# 2       x,  資訊學院          [不在學校],                 x,            [不在學校],
#
#                  星期五
# 0  [AA科技大樓],[0-5分鐘],
# 1            [不在學校],
# 2           [不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 65, 71]
#                                          星期一 major  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
# 2  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
#
#                                        星期二  \
# 0  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
# 2  [P觀光語文大樓],[5-10分鐘],,[P觀光語文大樓],[5-10分鐘],
#
#                                        星期三  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期四  \
# 0  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期五
# 0                                 [不在學校],,
# 1  [P觀光語文大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 8]
# timetemp
# [22, 25, 28]
# timetemp
# [32, 35, 28]
# timetemp
# [39, 35, 28]
#                    星期一 major                                      星期二  \
# 0  [EE綜合教學大樓],[0-5分鐘],  資訊學院                          [體育一館],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],  資訊學院  [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2   [S資訊管理大樓],[0-5分鐘],  資訊學院                       [S資訊管理大樓],[0-5分鐘],
#
#                   星期三                  星期四                  星期五
# 0   [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],             [不在學校],,
# 1  [S資訊管理大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],  [CC資訊網路大樓],[0-5分鐘],
# 2   [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],    [AA科技大樓],[0-5分鐘],
# timetemp
# [2, 6, 12]
# timetemp
# [19, 25, 31]
# timetemp
# [37, 41, 47]
# timetemp
# [54, 60, 66]
# timetemp
# [73, 77, 81]
#                                          星期一 major  \
# 0                            [不在學校],,[不在學校],  資訊學院
# 1  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],  資訊學院
# 2    [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
#
#                                          星期二  \
# 0          [體育一館],[5-10分鐘],,[體育一館],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                          [不在學校],,[不在學校],x,
#
#                                        星期三  \
# 0                          [不在學校],,[不在學校],
# ...
# 1                             [學校宿舍],[0-5分鐘],  設計學院
# 2                             [學校宿舍],[0-5分鐘],  設計學院
#
#                                     星期二                                   星期三  \
# 0  [M設計大樓],[10-15分鐘],,[M設計大樓],[5-10分鐘],  [M設計大樓],[10-15分鐘],,[M設計大樓],[5-10分鐘],
# 1                       [學校宿舍],[0-5分鐘],                     [M設計大樓],[5-10分鐘],
# 2                       [學校宿舍],[0-5分鐘],                       [學校宿舍],[0-5分鐘],
#
#                                星期四                              星期五
# 0  [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],  [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# 1                  [體育一館],[0-5分鐘],                [M設計大樓],[5-10分鐘],
# 2                  [學校宿舍],[0-5分鐘],                 [學校宿舍],[0-5分鐘],,
# timetemp
# [2, 6, 12]
# timetemp
# [17, 23, 29]
# timetemp
# [34, 40, 46]
# timetemp
# [51, 57, 63]
# timetemp
# [68, 74, 78]
#                                      星期一  major  \
# 0                        [不在學校],,[不在學校],  社會科學院
# 1  [EE綜合教學大樓],[5-10分鐘],,[M設計大樓],[0-5分鐘],  社會科學院
# 2                        [不在學校],,[不在學校],  社會科學院
#
#                                          星期二  \
# 0      [BB社科大樓],[5-10分鐘],,[BB社科大樓],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                            [不在學校],,[不在學校],
#
#                                      星期三  \
# 0  [BB社科大樓],[5-10分鐘],,[BB社科大樓],[5-10分鐘],
# 1    [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# 2                        [不在學校],,[不在學校],
#
#                                      星期四                          星期五
# 0  [BB社科大樓],[5-10分鐘],,[BB社科大樓],[5-10分鐘],  [操場],[0-5分鐘],,[操場],[0-5分鐘],
# 1   [EE綜合教學大樓],[5-10分鐘],,[體育二館],[0-5分鐘],              [不在學校],,[不在學校],
# 2                        [不在學校],,[不在學校],             [不在學校],,[不在學校],,
# timetemp
# [0, 2, 0]
# timetemp
# [6, 2, 0]
# timetemp
# [6, 2, 0]
# timetemp
# [11, 17, 0]
# timetemp
# [11, 17, 0]
#                      星期一  major                    星期二                    星期三  \
# 0                x,x,x,x  社會科學院     [BB社科大樓],[5-10分鐘],     [BB社科大樓],[5-10分鐘],
# 1  [CC資訊網路大樓],[10-15分鐘],  社會科學院  [CC資訊網路大樓],[10-15分鐘],  [CC資訊網路大樓],[10-15分鐘],
# 2                x,x,x,x  社會科學院                x,x,x,x                x,x,x,x
#
#                                        星期四  \
# 0  [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# 1                    [EE綜合教學大樓],[10-15分鐘],
# 2                                  x,x,x,x
#
#                                        星期五
# 0  [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# 1                    [EE綜合教學大樓],[10-15分鐘],
# 2                                  x,x,x,x
# timetemp
# [2, 4, 7]
# timetemp
# [10, 13, 16]
# timetemp
# [19, 21, 24]
# timetemp
# [28, 31, 34]
# timetemp
# [37, 39, 42]
#                  星期一 major                    星期二                    星期三  \
# 0            [不在學校],  資訊學院  [EE綜合教學大樓],[10-15分鐘],                [不在學校],
# 1  [AA科技大樓],[0-5分鐘],  資訊學院      [AA科技大樓],[0-5分鐘],  [EE綜合教學大樓],[10-15分鐘],
# 2            [不在學校],  資訊學院                [不在學校],    [S資訊管理大樓],[5-10分鐘],
#
#                  星期四                 星期五
# 0  [AA科技大樓],[0-5分鐘],             [不在學校],
# 1  [AA科技大樓],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],
# 2            [不在學校],            [不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 45, 51]
# timetemp
# [58, 64, 70]
# timetemp
# [77, 83, 89]
#                                    星期一  major  \
# 0  [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],  社會科學院
# 1  [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],  社會科學院
# 2  [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],  社會科學院
#
#                                       星期二  \
# 0  [FF國際大樓],[10-15分鐘],,[AA科技大樓],[5-10分鐘],
# 1   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# 2   [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
#
#                                          星期三  \
# 0                    x,,[S資訊管理大樓],[10-15分鐘],
# 1  [S資訊管理大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# 2  [S資訊管理大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
#
#                                          星期四  \
# 0    [室外籃球場],[15-20分鐘],,[P觀光語文大樓],[15-20分鐘],
# 1  [P觀光語文大樓],[15-20分鐘],,[P觀光語文大樓],[15-20分鐘],
# 2  [P觀光語文大樓],[15-20分鐘],,[P觀光語文大樓],[15-20分鐘],
#
#                                          星期五
# 0      [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# 1  [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# 2  [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                          星期一 major  \
# 0            [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],  觀光學院
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],  觀光學院
# 2                 [不在學校],x,,[學校宿舍],[5-10分鐘],  觀光學院
#
#                                          星期二  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                 [不在學校],x,,[學校宿舍],[5-10分鐘],
#
#                                          星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                 [不在學校],x,,[學校宿舍],[5-10分鐘],
#
#                                          星期四  \
# 0  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 1  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# 2                 [不在學校],x,,[學校宿舍],[5-10分鐘],
#
#                                    星期五
# 0  [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# 1       [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# 2           [不在學校],x,,[學校宿舍],[5-10分鐘],
# timetemp
# [2, 6, 9]
# timetemp
# [12, 16, 19]
# timetemp
# [22, 26, 29]
# timetemp
# [32, 36, 39]
# timetemp
# [42, 48, 51]
#                       星期一 major                    星期二                    星期三  \
# 0  [EE綜合教學大樓],[5-10分鐘],x,  資訊學院  [S資訊管理大樓],[5-10分鐘],x,  [S資訊管理大樓],[5-10分鐘],x,
# 1      [S資訊管理大樓],[0-5分鐘],  資訊學院     [S資訊管理大樓],[0-5分鐘],     [S資訊管理大樓],[0-5分鐘],
# 2                 [不在學校],  資訊學院                [不在學校],                [不在學校],
#
#                    星期四                                          星期五
# 0  [M設計大樓],[5-10分鐘],x,  [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# 1   [S資訊管理大樓],[0-5分鐘],                           [S資訊管理大樓],[0-5分鐘],
# 2              [不在學校],                                     [不在學校],,
# timetemp
# [2, 5, 8]
# timetemp
# [11, 14, 17]
# timetemp
# [20, 23, 25]
# timetemp
# [28, 31, 34]
# timetemp
# [37, 40, 42]
#                    星期一      major                  星期二                  星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],  教育暨應用語文學院  [EE綜合教學大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],  教育暨應用語文學院  [EE綜合教學大樓],[0-5分鐘],              [不在學校],
# 2              [不在學校],  教育暨應用語文學院              [不在學校],              [不在學校],
#
#                    星期四                  星期五
# 0  [EE綜合教學大樓],[0-5分鐘],  [EE綜合教學大樓],[0-5分鐘],
# 1  [EE綜合教學大樓],[0-5分鐘],              [不在學校],
# 2              [不在學校],             [不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                  星期一 major                                星期二  \
# 0  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 1  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 2  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
#
#                                  星期三                                星期四  \
# 0  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 1  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
# 2  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],,[M設計大樓],[0-5分鐘],
#
#                           星期五
# 0  [不在學校],x,,[M設計大樓],[0-5分鐘],
# 1  [M設計大樓],[0-5分鐘],,[不在學校],x,
# 2         [不在學校],x,,[不在學校],x,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 18]
# timetemp
# [22, 25, 28]
# timetemp
# [32, 35, 38]
# timetemp
# [42, 45, 48]
#                    星期一 major               星期二               星期三  \
# 0  [P觀光語文大樓],[5-10分鐘],  設計學院  [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],
# 1     [M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[0-5分鐘],  [M設計大樓],[0-5分鐘],
# 2     [M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[0-5分鐘],         [不在學校],x,
#
#                 星期四         星期五
# 0  [M設計大樓],[0-5分鐘],   [不在學校],x,
# 1  [M設計大樓],[0-5分鐘],   [不在學校],x,
# 2         [不在學校],x,  [不在學校],x,,
# timetemp
# [2, 8, 13]
# timetemp
# [17, 23, 28]
# timetemp
# [32, 38, 43]
# timetemp
# [47, 50, 55]
# timetemp
# [62, 65, 70]
#                                   星期一  major  \
# 0  [BB社科大樓],[5-10分鐘],,[學校宿舍],[0-5分鐘],  社會科學院
# 1               [BB社科大樓],[5-10分鐘],,x,  社會科學院
# 2                     [學校宿舍],[0-5分鐘],  社會科學院
#
#                                      星期二  \
# 0  [P觀光語文大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# 1                     [學校宿舍],[0-5分鐘],,x,
# 2                        [學校宿舍],[0-5分鐘],
#
#                                      星期三                            星期四  \
# 0  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],                [學校宿舍],[0-5分鐘],
# 1                     [學校宿舍],[0-5分鐘],,x,             [學校宿舍],[0-5分鐘],,x,
# 2                        [學校宿舍],[0-5分鐘],  [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
#
#                              星期五
# 0                [學校宿舍],[0-5分鐘],
# 1             [學校宿舍],[0-5分鐘],,x,
# 2  [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [36, 40, 46]
# timetemp
# [53, 59, 65]
# timetemp
# [70, 72, 74]
#                                    星期一 major  \
# 0  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 1  [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],  資訊學院
# 2                      [不在學校],,[不在學校],  資訊學院
#
#                                          星期二  \
# 0  [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# 1            [體育一館],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                            [不在學校],,[不在學校],
#
#                                      星期三  \
# 0                        [不在學校],,[不在學校],
# 1    [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# 2  [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
#
#                                          星期四               星期五
# 0  [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],           [不在學校],
# 1      [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],           [不在學校],
# 2                            [不在學校],,[不在學校],  [不在學校],,[不在學校],,
# timetemp
# [2, 5, 8]
# timetemp
# [12, 15, 18]
# timetemp
# [22, 25, 28]
# timetemp
# [31, 33, 35]
# timetemp
# [38, 40, 42]
#                 星期一 major                星期二                星期三      星期四  \
# 0  [M設計大樓],[0-5分鐘],  設計學院   [M設計大樓],[0-5分鐘],  [M設計大樓],[5-10分鐘],  [不在學校],
# 1  [M設計大樓],[0-5分鐘],  設計學院  [M設計大樓],[5-10分鐘],  [M設計大樓],[5-10分鐘],  [不在學校],
# 2  [室外籃球場],[0-5分鐘],  設計學院    [體育一館],[0-5分鐘],            [不在學校],  [不在學校],
#
#         星期五
# 0   [不在學校],
# 1   [不在學校],
# 2  [不在學校],,
# timetemp
# [2, 8, 14]
# timetemp
# [21, 27, 33]
# timetemp
# [40, 46, 52]
# timetemp
# [59, 65, 71]
# timetemp
# [78, 84, 90]
#                                        星期一 major  \
# 0   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],  資訊學院
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],  資訊學院
#
#                                        星期二  \
# 0   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期三  \
# 0   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期四  \
# 0   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
#
#                                        星期五
# 0   [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# 2  [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# timetemp
# [2, 8, 14]
# timetemp
# [19, 25, 31]
# timetemp
# [36, 42, 48]
# timetemp
# [54, 60, 66]
# timetemp
# [71, 77, 83]
#                                        星期一 major  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],  資訊學院
# 1         [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],  資訊學院
# 2                          [不在學校],,[不在學校],  資訊學院
#
#                                        星期二  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1         [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 2                          [不在學校],,[不在學校],
#
#                                        星期三  \
# 0  [EE綜合教學大樓],[0-5分鐘],,[EE綜合教學大樓],[0-5分鐘],
# 1  [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2            [Q行政大樓OR圖書館],[0-5分鐘],,[不在學校],
#
#                                            星期四  \
# 0  [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 1           [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                              [不在學校],,[不在學校],
#
#                                            星期五
# 0  [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# 1          [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# 2                             [不在學校],,[不在學校],,
# timetemp
# [2, 5, 0]
# timetemp
# [9, 12, 0]
# timetemp
# [16, 19, 0]
# timetemp
# [23, 26, 0]
# timetemp
# [30, 33, 0]
#                    星期一 major                 星期二                  星期三  \
# 0   [AA科技大樓],[5-10分鐘],  資訊學院  [BB社科大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],  資訊學院  [AA科技大樓],[5-10分鐘],  [S資訊管理大樓],[5-10分鐘],
# 2              x,x,x,x  資訊學院             x,x,x,x              x,x,x,x
#
#                    星期四                  星期五
# 0   [AA科技大樓],[5-10分鐘],   [AA科技大樓],[5-10分鐘],
# 1  [S資訊管理大樓],[5-10分鐘],  [AA科技大樓],[5-10分鐘],,
# 2              x,x,x,x              x,x,x,x
#    major                               星期一  \
# 0   資訊學院                [S資訊管理大樓],[0-5分鐘],
# 1   資訊學院                 [AA科技大樓],[0-5分鐘],
# 2   資訊學院                           [不在學校],
# 0   資訊學院                   [體育一館],[0-5分鐘],
# 1   資訊學院                   [體育一館],[0-5分鐘],
# ..   ...                               ...
# 1   資訊學院  [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 2   資訊學院                   [不在學校],,[不在學校],
# 0   資訊學院                [AA科技大樓],[5-10分鐘],
# 1   資訊學院               [S資訊管理大樓],[5-10分鐘],
# 2   資訊學院                           x,x,x,x
#
#                                         星期三  \
# 0                      [EE綜合教學大樓],[5-10分鐘],
# 1                                   [不在學校],
# 2                                   [不在學校],
# 0                           [體育一館],[0-5分鐘],
# 1                          [M設計大樓],[0-5分鐘],
# ..                                      ...
# 1   [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 2             [Q行政大樓OR圖書館],[0-5分鐘],,[不在學校],
# 0                        [AA科技大樓],[5-10分鐘],
# 1                       [S資訊管理大樓],[5-10分鐘],
# 2                                   x,x,x,x
#
#                                        星期二  \
# 0   [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                       [S資訊管理大樓],[0-5分鐘],
# 2                                  [不在學校],
# 0                       [S資訊管理大樓],[0-5分鐘],
# 1                         [M設計大樓],[0-5分鐘],
# ..                                     ...
# 1         [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 2                          [不在學校],,[不在學校],
# 0                       [BB社科大樓],[5-10分鐘],
# 1                       [AA科技大樓],[5-10分鐘],
# 2                                  x,x,x,x
#
#                                     星期五                                 星期四
# 0                    [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1                               [不在學校],                             [不在學校],
# 2                              [不在學校],,                             [不在學校],
# 0                    [S資訊管理大樓],[0-5分鐘],                  [S資訊管理大樓],[0-5分鐘],
# 1                      [體育一館],[0-5分鐘],,                     [體育一館],[0-5分鐘],
# ..                                  ...                                 ...
# 1   [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 2                      [不在學校],,[不在學校],,                     [不在學校],,[不在學校],
# 0                    [AA科技大樓],[5-10分鐘],                  [AA科技大樓],[5-10分鐘],
# 1                   [AA科技大樓],[5-10分鐘],,                 [S資訊管理大樓],[5-10分鐘],
# 2                               x,x,x,x                             x,x,x,x
#
# [387 rows x 6 columns]
# [0, 0, 0, 0, 0]
# ['資訊學院', '星期一', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期二', '上午', '[BB社科大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '星期三', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期四', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期五', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '', '早餐', 'x', '幾點', '8-9時', '等候時間', '20-30分鐘\n']

# %%
import pandas as pd
import csv
import numpy as np
data = pd.read_csv('123.csv',encoding='big5')
print(data)
data1=[]
ntext=[]
data1=data.iloc[:, 1]

print(data.iloc[:, 1])
print(data1[0])
for co in range(len(data1)):
    ntext=data1[0].split(',')
    for w in range(3):
        if '' in ntext[w]:
            ntext[w]='x'
print(ntext[0])
# Out:
#      Unnamed: 0                               星期一  \
# 0             0                [S資訊管理大樓],[0-5分鐘],
# 1             1                 [AA科技大樓],[0-5分鐘],
# 2             2                           [不在學校],
# 3             0                   [體育一館],[0-5分鐘],
# 4             1                   [體育一館],[0-5分鐘],
# ..          ...                               ...
# 382           1  [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383           2                   [不在學校],,[不在學校],
# 384           0                [AA科技大樓],[5-10分鐘],
# 385           1               [S資訊管理大樓],[5-10分鐘],
# 386           2                           x,x,x,x
#
#                                         星期二  \
# 0    [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                        [S資訊管理大樓],[0-5分鐘],
# 2                                   [不在學校],
# 3                        [S資訊管理大樓],[0-5分鐘],
# 4                          [M設計大樓],[0-5分鐘],
# ..                                      ...
# 382        [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                         [不在學校],,[不在學校],
# 384                      [BB社科大樓],[5-10分鐘],
# 385                      [AA科技大樓],[5-10分鐘],
# 386                                 x,x,x,x
#
#                                          星期三  \
# 0                       [EE綜合教學大樓],[5-10分鐘],
# 1                                    [不在學校],
# 2                                    [不在學校],
# 3                            [體育一館],[0-5分鐘],
# 4                           [M設計大樓],[0-5分鐘],
# ..                                       ...
# 382  [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 383            [Q行政大樓OR圖書館],[0-5分鐘],,[不在學校],
# 384                       [AA科技大樓],[5-10分鐘],
# 385                      [S資訊管理大樓],[5-10分鐘],
# 386                                  x,x,x,x
#
#                                     星期四                                  星期五  \
# 0                    [S資訊管理大樓],[0-5分鐘],                   [S資訊管理大樓],[0-5分鐘],
# 1                               [不在學校],                              [不在學校],
# 2                               [不在學校],                             [不在學校],,
# 3                    [S資訊管理大樓],[0-5分鐘],                   [S資訊管理大樓],[0-5分鐘],
# 4                       [體育一館],[0-5分鐘],                     [體育一館],[0-5分鐘],,
# ..                                  ...                                  ...
# 382  [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],  [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                     [不在學校],,[不在學校],                     [不在學校],,[不在學校],,
# 384                  [AA科技大樓],[5-10分鐘],                   [AA科技大樓],[5-10分鐘],
# 385                 [S資訊管理大樓],[5-10分鐘],                  [AA科技大樓],[5-10分鐘],,
# 386                             x,x,x,x                              x,x,x,x
#
#     major
# 0    資訊學院
# 1    資訊學院
# 2    資訊學院
# 3    資訊學院
# 4    資訊學院
# ..    ...
# 382  資訊學院
# 383  資訊學院
# 384  資訊學院
# 385  資訊學院
# 386  資訊學院
#
# [387 rows x 7 columns]
# 0                    [S資訊管理大樓],[0-5分鐘],
# 1                     [AA科技大樓],[0-5分鐘],
# 2                               [不在學校],
# 3                       [體育一館],[0-5分鐘],
# 4                       [體育一館],[0-5分鐘],
#                      ...
# 382    [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                     [不在學校],,[不在學校],
# 384                  [AA科技大樓],[5-10分鐘],
# 385                 [S資訊管理大樓],[5-10分鐘],
# 386                             x,x,x,x
# Name: 星期一, Length: 387, dtype: object
# [S資訊管理大樓],[0-5分鐘],
# ['x', 'x', 'x']
# x

# %%
import pandas as pd
import csv
import numpy as np
data = pd.read_csv('123.csv',encoding='big5')
#print(data)
data1=[]
ntext=[]
o=[1,2,3,4,5]
temp=[0,0,0,0]
t=0
print(data.iloc[:, 1])
#print(data1[0])
for ii in range(1,6):
    data1=data.iloc[:, ii]
    for co in range(len(data1)):
        ntext=data1[co].split(',')
        #print(ntext)
        for w in range(len(ntext)):
            print(ntext[w])
            print(data1[co])
            print('co')

            print('----------')
            if any(ntext[w])==True:
                temp[t]=ntext[w]
                t=t+1
                tt=t
        for ii in range((3-(tt-1))):
            temp[t]='x'
            t=t+1
        t=0
        data1[co]=temp
        temp=[0,0,0,0]
    
    data.iloc[:,ii]=data1
    data1=[]
print(data.iloc[:,1])
    
print(ntext)
data.to_csv('new123.csv',encoding='big5')
# Out:
# 0                    [S資訊管理大樓],[0-5分鐘],
# 1                     [AA科技大樓],[0-5分鐘],
# 2                               [不在學校],
# 3                       [體育一館],[0-5分鐘],
# 4                       [體育一館],[0-5分鐘],
#                      ...
# 382    [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                     [不在學校],,[不在學校],
# 384                  [AA科技大樓],[5-10分鐘],
# 385                 [S資訊管理大樓],[5-10分鐘],
# 386                             x,x,x,x
# Name: 星期一, Length: 387, dtype: object
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [體育一館]
# [體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [體育一館],[0-5分鐘],
# co
# ----------
#
# [體育一館],[0-5分鐘],
# co
# ----------
# [體育一館]
# [體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [體育一館],[0-5分鐘],
# co
# ----------
#
# [體育一館],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [體育一館]
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# x
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [二餐]
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [二餐],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [不在學校],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [不在學校],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [BB社科大樓]
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [BB社科大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [BB社科大樓]
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
#
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [BB社科大樓]
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
#
# [BB社科大樓],[0-5分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],,x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [一餐]
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[不在學校],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,x,
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,x,
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,x,
# co
# ----------
# x
# [AA科技大樓],[0-5分鐘],,x,
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [BB社科大樓]
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[BB社科大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,x,
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,x,
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,x,
# co
# ----------
# x
# [S資訊管理大樓],[5-10分鐘],,x,
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# x
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
# x
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
# [體育一館]
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[體育一館],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],x,
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],x,
# co
# ----------
# x
# [S資訊管理大樓],[0-5分鐘],x,
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [體育一館]
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [體育一館]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [體育一館]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# C:\Users\schoolpc\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ----------
# x
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# x
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],
# co
# ----------
# [5-10分鐘]
# [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],
# co
# ----------
#
# [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],
# co
# ----------
#
# [Q行政大樓OR圖書館],[5-10分鐘],,[不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
# x
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# x
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],
# co
# ----------
#
# [學校宿舍],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [不在學校],,[EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [不在學校],,[EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
# [S資訊管理大樓]
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[10-15分鐘],,[S資訊管理大樓],[10-15分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
# [10-15分鐘]
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
#
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
# x
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
#
# [S資訊管理大樓],[10-15分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
# x
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],,[CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# x
# x,,x,
# co
# ----------
#
# x,,x,
# co
# ----------
# x
# x,,x,
# co
# ----------
#
# x,,x,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [AA科技大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [不在學校],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [不在學校]
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[不在學校],
# co
# ----------
# [Q行政大樓OR圖書館]
# [Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
# x
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
#
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
# [操場]
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
#
# [不在學校],x,,[操場],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# x
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],x,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [AA科技大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [P觀光語文大樓]
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [5-10分鐘]
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
#
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# x
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
#
# [P觀光語文大樓],[5-10分鐘],,[不在學校],x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],x,
# co
# ----------
# x
# [不在學校],,[不在學校],x,
# co
# ----------
#
# [不在學校],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
#
# [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# co
# ----------
# [操場]
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [操場],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# ...
# ----------
# x
# x,,
# co
# ----------
#
# x,,
# co
# ----------
#
# x,,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [10-15分鐘]
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[10-15分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [M設計大樓]
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
# [P觀光語文大樓]
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[P觀光語文大樓],[0-5分鐘],
# co
# ----------
# [M設計大樓]
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [一餐]
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,
# co
# ----------
# x
# [不在學校],x,,
# co
# ----------
#
# [不在學校],x,,
# co
# ----------
#
# [不在學校],x,,
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [室外籃球場]
# [室外籃球場],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [室外籃球場],[0-5分鐘],
# co
# ----------
#
# [室外籃球場],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# x
# x,
# co
# ----------
#
# x,
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],,[AA科技大樓],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,幾點,
# co
# ----------
#
# [不在學校],,[不在學校],,幾點,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,幾點,
# co
# ----------
#
# [不在學校],,[不在學校],,幾點,
# co
# ----------
# 幾點
# [不在學校],,[不在學校],,幾點,
# co
# ----------
#
# [不在學校],,[不在學校],,幾點,
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [M設計大樓]
# [M設計大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [M設計大樓],[5-10分鐘],
# co
# ----------
#
# [M設計大樓],[5-10分鐘],
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],,
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],,
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,
# co
# ----------
# [操場]
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
#
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
# [操場]
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
#
# [操場],[0-5分鐘],,[操場],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],
# co
# ----------
#
# [不在學校],,[不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [BB社科大樓]
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
# [5-10分鐘]
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
#
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
# [P觀光語文大樓]
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
#
# [BB社科大樓],[5-10分鐘],,[P觀光語文大樓],[10-15分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[10-15分鐘],
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [體育一館]
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [EE綜合教學大樓]
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [體育一館],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [20分鐘以上]
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
#
# [EE綜合教學大樓],[20分鐘以上],,[EE綜合教學大樓],[20分鐘以上],
# co
# ----------
# [M設計大樓]
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
#
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
# [M設計大樓]
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
#
# [M設計大樓],[5-10分鐘],,[M設計大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# x
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[EE綜合教學大樓],[5-10分鐘],
# co
# ----------
# [不在學校]
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
# x
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
# [學校宿舍]
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
#
# [不在學校],x,,[學校宿舍],[5-10分鐘],
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [CC資訊網路大樓]
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [10-15分鐘]
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[10-15分鐘],,[CC資訊網路大樓],[10-15分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [EE綜合教學大樓]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
#
# [EE綜合教學大樓],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
# x
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
# [M設計大樓]
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
#
# [不在學校],x,,[M設計大樓],[0-5分鐘],
# co
# ----------
# [M設計大樓]
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [0-5分鐘]
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# x
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
#
# [M設計大樓],[0-5分鐘],,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,[不在學校],x,
# co
# ----------
# x
# [不在學校],x,,[不在學校],x,
# co
# ----------
#
# [不在學校],x,,[不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,
# co
# ----------
# x
# [不在學校],x,
# co
# ----------
#
# [不在學校],x,
# co
# ----------
# [不在學校]
# [不在學校],x,,
# co
# ----------
# x
# [不在學校],x,,
# co
# ----------
#
# [不在學校],x,,
# co
# ----------
#
# [不在學校],x,,
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],
# co
# ----------
#
# [學校宿舍],[0-5分鐘],
# co
# ----------
# [學校宿舍]
# [學校宿舍],[0-5分鐘],,x,
# co
# ----------
# [0-5分鐘]
# [學校宿舍],[0-5分鐘],,x,
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,x,
# co
# ----------
# x
# [學校宿舍],[0-5分鐘],,x,
# co
# ----------
#
# [學校宿舍],[0-5分鐘],,x,
# co
# ----------
# [操場]
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
#
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [學校宿舍]
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
#
# [操場],[0-5分鐘],,[學校宿舍],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],
# co
# ----------
#
# [不在學校],
# co
# ----------
# [不在學校]
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
#
# [不在學校],,
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[0-5分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [S資訊管理大樓]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
#
# [S資訊管理大樓],[5-10分鐘],,[S資訊管理大樓],[5-10分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
#
# [Q行政大樓OR圖書館],[0-5分鐘],,[Q行政大樓OR圖書館],[0-5分鐘],
# co
# ----------
# [Q行政大樓OR圖書館]
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [一餐]
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [0-5分鐘]
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
#
# [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [不在學校]
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
#
# [不在學校],,[不在學校],,
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],
# co
# ----------
# [AA科技大樓]
# [AA科技大樓],[5-10分鐘],,
# co
# ----------
# [5-10分鐘]
# [AA科技大樓],[5-10分鐘],,
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,
# co
# ----------
#
# [AA科技大樓],[5-10分鐘],,
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# x
# x,x,x,x
# co
# ----------
# 0                  [[S資訊管理大樓], [0-5分鐘], x, x]
# 1                           [[不在學校], x, x, x]
# 2                           [[不在學校], x, x, x]
# 3                  [[S資訊管理大樓], [0-5分鐘], x, x]
# 4                     [[體育一館], [0-5分鐘], x, x]
#                         ...
# 382    [[Q行政大樓OR圖書館], [0-5分鐘], [一餐], [0-5分鐘]]
# 383                    [[不在學校], [不在學校], x, x]
# 384                [[AA科技大樓], [5-10分鐘], x, x]
# 385                [[AA科技大樓], [5-10分鐘], x, x]
# 386                              [x, x, x, x]
# Name: 星期一, Length: 387, dtype: object
# ['x', 'x', 'x', 'x']

# %%
data = pd.read_csv('123.csv',encoding='big5')
for ii in range(1,6):
    data1=data.iloc[:, ii]
    print(data1)
# Out:
# 0                    [S資訊管理大樓],[0-5分鐘],
# 1                     [AA科技大樓],[0-5分鐘],
# 2                               [不在學校],
# 3                       [體育一館],[0-5分鐘],
# 4                       [體育一館],[0-5分鐘],
#                      ...
# 382    [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                     [不在學校],,[不在學校],
# 384                  [AA科技大樓],[5-10分鐘],
# 385                 [S資訊管理大樓],[5-10分鐘],
# 386                             x,x,x,x
# Name: 星期一, Length: 387, dtype: object
# 0      [EE綜合教學大樓],[0-5分鐘],,[S資訊管理大樓],[0-5分鐘],
# 1                          [S資訊管理大樓],[0-5分鐘],
# 2                                     [不在學校],
# 3                          [S資訊管理大樓],[0-5分鐘],
# 4                            [M設計大樓],[0-5分鐘],
#                         ...
# 382          [S資訊管理大樓],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                           [不在學校],,[不在學校],
# 384                        [BB社科大樓],[5-10分鐘],
# 385                        [AA科技大樓],[5-10分鐘],
# 386                                   x,x,x,x
# Name: 星期二, Length: 387, dtype: object
# 0                         [EE綜合教學大樓],[5-10分鐘],
# 1                                      [不在學校],
# 2                                      [不在學校],
# 3                              [體育一館],[0-5分鐘],
# 4                             [M設計大樓],[0-5分鐘],
#                         ...
# 382    [CC資訊網路大樓],[0-5分鐘],,[CC資訊網路大樓],[0-5分鐘],
# 383              [Q行政大樓OR圖書館],[0-5分鐘],,[不在學校],
# 384                         [AA科技大樓],[5-10分鐘],
# 385                        [S資訊管理大樓],[5-10分鐘],
# 386                                    x,x,x,x
# Name: 星期三, Length: 387, dtype: object
# 0                      [S資訊管理大樓],[0-5分鐘],
# 1                                 [不在學校],
# 2                                 [不在學校],
# 3                      [S資訊管理大樓],[0-5分鐘],
# 4                         [體育一館],[0-5分鐘],
#                       ...
# 382    [S資訊管理大樓],[0-5分鐘],,[體育一館],[0-5分鐘],
# 383                       [不在學校],,[不在學校],
# 384                    [AA科技大樓],[5-10分鐘],
# 385                   [S資訊管理大樓],[5-10分鐘],
# 386                               x,x,x,x
# Name: 星期四, Length: 387, dtype: object
# 0                       [S資訊管理大樓],[0-5分鐘],
# 1                                  [不在學校],
# 2                                 [不在學校],,
# 3                       [S資訊管理大樓],[0-5分鐘],
# 4                         [體育一館],[0-5分鐘],,
#                       ...
# 382    [Q行政大樓OR圖書館],[0-5分鐘],,[一餐],[0-5分鐘],
# 383                       [不在學校],,[不在學校],,
# 384                     [AA科技大樓],[5-10分鐘],
# 385                    [AA科技大樓],[5-10分鐘],,
# 386                                x,x,x,x
# Name: 星期五, Length: 387, dtype: object
