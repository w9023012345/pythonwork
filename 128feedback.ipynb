# %%
import re
f = open('C:/Users/schoolpc/Desktop/128feedback.csv', "r",encoding="utf-8")
text = []
newxtext=[]
ntext =[]
fp = open("filename.txt", "a")
for line in f:
    text.append(line)
    

for w in range(len(text)):
    ntext ="".join(text[0]).split(',')
    for q in range(len(ntext)):
        newxtext.append(ntext[q].replace(" ",""))
    for q in range(len(ntext)):
        newxtext[q]=newxtext[q].replace("_","")   
        txt="".join(newxtext[q])
        fp.write(txt)
        fp.write('\n')
print(newxtext[0:100])



fp.close()
# Out:
# ['時間戳記', '1.請問是哪個學院的老師或學生?', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[BB社科大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[AA科技大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[S資訊管理大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[P觀光語文大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[EE綜合教學大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[CC資訊網路大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[M設計大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[Q行政大樓OR圖書館]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[體育一館]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[室外籃球場]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[FF國際大樓]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[操場]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[一餐]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[二餐]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份)[三餐]"', '"2.一周內，上午會待在學校的哪裡?(若有""次要""的地點，請繼續填第4題，若無，可跳下一部份
# ...

# %%
import re
f = open('C:/Users/schoolpc/Desktop/128feedback.csv', "r",encoding="utf-8")
fp = open("finaltext.txt", "a")
text = []
newxtext=[]
ntext =[]
txt=[]
for line in f:
    text.append(line)
for w in range(len(text)):
    if '2019/10/6' in text[w]:
        print(w)
for co in range(153,len(text)):
    txt="".join(text[co])
    #print(txt)
    txt=txt.split('"')
    for w in range(len(txt)):
        txt[w]=txt[w].replace(", ","")
    txt="".join(txt)
    txt=txt.split(',')
    
    print(text[0])
    print(txt[1])
    finaltext=[]
    finaltext.append(txt[1])
    finaltext.append(",")
    finaltext.append('星期一')
    finaltext.append(",")
    for w in range(len(txt)):
        txt[w]=txt[w].replace("\n","")
    for w in range(1,len(txt)):
        if'星期一' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期二')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期二' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期三')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期三' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期四')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期四' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期五')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期五' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    for w in range(140,len(txt)):
        if txt[w] is not '':
            finaltext.append(text[w-1])
            finaltext.append(",")
            finaltext.append(txt[w])
    for w in range(len(finaltext)):
        finaltext[w]=finaltext[w].strip('\n')
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "分鐘" in finaltext[w]:
            for ww in range(1,3):
                if w+ww ==len(finaltext):
                    break
                if "上午" in finaltext[w+ww] or "下午" in finaltext[w+ww] or "晚上" in finaltext[w+ww]or "星期五" in finaltext[w+ww]or "星期四" in finaltext[w+ww]or "星期三" in finaltext[w+ww]or "星期二" in finaltext[w+ww]or "星期一" in finaltext[w+ww]:
                    break
                if "分鐘" in finaltext[w+ww]:
                    finaltext[w+ww]='x'
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "不在學校" in finaltext[w]:
            for ww in range(1,10):
                if w+ww ==len(finaltext):
                    break
                if "上午" in finaltext[w+ww] or "下午" in finaltext[w+ww] or "晚上" in finaltext[w+ww]or "星期五" in finaltext[w+ww]or "星期四" in finaltext[w+ww]or "星期三" in finaltext[w+ww]or "星期二" in finaltext[w+ww]or "星期一" in finaltext[w+ww]:
                    break
                if "分鐘" in finaltext[w+ww]:
                    finaltext[w+ww]='x'
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "早餐" in finaltext[w] or "午餐" in finaltext[w] or "晚餐" in finaltext[w]:
            for ww in range(1,5):
                if w+ww == len(finaltext):
                    break
                if "不在學校" in finaltext[w+ww]:
                    for www in range(1,100):
                        if w+ww+www == len(finaltext):
                            break
                        if "早餐" in finaltext[w+ww+www] or "午餐" in finaltext[w+ww+www] or "晚餐" in finaltext[w+ww+www]:
                            break
                        finaltext[w+ww+www] = 'x' 

    finaltext.append('\n')
    
    finaltext="".join(finaltext)
    print(len(txt))
    print(co)
    print(txt[146])
    print(finaltext)
    
    fp.write(finaltext)



# 寫入 This is a testing! 到檔案

# 關閉檔案
fp.close()
# Out:
# 153
# 154
# 155
# 156
# 157
# ﻿1.請問是哪個學院的老師或學生?
#
# 資訊學院
# 154
# 153
#
# 資訊學院,星期一,上午,[S資訊管理大樓],[0-5分鐘],下午,[AA科技大樓],[0-5分鐘],晚上,[不在學校],星期二,上午,[EE綜合教學大樓],[0-5分鐘],上午,[S資訊管理大樓],[0-5分鐘],下午,[S資訊管理大樓],[0-5分鐘],晚上,[不在學校],星期三,上午,[EE綜合教學大樓],[5-10分鐘],下午,[不在學校],晚上,[不在學校],星期四,上午,[S資訊管理大樓],[0-5分鐘],下午,[不在學校],晚上,[不在學校],星期五,上午,[S資訊管理大樓],[0-5分鐘],下午,[不在學校],晚上,[不在學校],,午餐,二餐(包含全家),幾點,11-12時,等候時間,10-20分鐘
#
# ﻿1.請問是哪個學院的老師或學生?
#
# 資訊學院
# 154
# 154
# 三餐
# 資訊學院,星期一,上午,[體育一館],[0-5分鐘],下午,[體育一館],[0-5分鐘],星期二,上午,[S資訊管理大樓],[0-5分鐘],下午,[M設計大樓],[0-5分鐘],晚上,[M設計大樓],[0-5分鐘],星期三,上午,[體育一館],[0-5分鐘],下午,[M設計大樓],[0-5分鐘],晚上,[M設計大樓],[0-5分鐘],星期四,上午,[S資訊管理大樓],[0-5分鐘],下午,[體育一館],[0-5分鐘],星期五,上午,[S資訊管理大樓],[0-5分鐘],下午,[體育一館],[0-5分鐘],,早餐,一餐(包含全家),幾點,8-9時,等候時間,0-10分鐘,午餐,三餐,幾點,12-13時,等候時間,0-10分鐘,晚餐,三餐,幾點,16-17時,等候時間,0-10分鐘
#
# ﻿1.請問是哪個學院的老師或學生?
#
# 資訊學院
# 154
# 155
# 一餐(包含全家)
# ...

# %%
import re
f = open('C:/Users/schoolpc/Desktop/128feedback.csv', "r",encoding="utf-8")
fp = open("finaltext.txt", "a")
text = []
newxtext=[]
ntext =[]
txt=[]
for line in f:
    text.append(line)
for w in range(len(text)):
    if '2019/10/6' in text[w]:
        print(w)
co1 =171
co2=co1+1
for co in range(co1,co2):
    txt="".join(text[co])
    #print(txt)
    txt=txt.split('"')
    for w in range(len(txt)):
        txt[w]=txt[w].replace(", ","")
    txt="".join(txt)
    txt=txt.split(',')
    
    print(text[0])
    print(txt[1])
    finaltext=[]
    finaltext.append(txt[1])
    finaltext.append(",")
    finaltext.append('星期一')
    finaltext.append(",")
    for w in range(len(txt)):
        txt[w]=txt[w].replace("\n","")
    for w in range(1,len(txt)):
        if'星期一' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期二')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期二' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期三')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期三' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期四')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期四' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    finaltext.append('星期五')
    finaltext.append(",")
    for w in range(1,len(txt)):
        if'星期五' in txt[w]:
            finaltext.append(text[w-1])
            finaltext.append(",")
    for w in range(140,len(txt)):
        if txt[w] is not '':
            finaltext.append(text[w-1])
            finaltext.append(",")
            finaltext.append(txt[w])
    for w in range(len(finaltext)):
        finaltext[w]=finaltext[w].strip('\n')
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "分鐘" in finaltext[w]:
            for ww in range(1,3):
                if w+ww ==len(finaltext):
                    break
                if "上午" in finaltext[w+ww] or "下午" in finaltext[w+ww] or "晚上" in finaltext[w+ww]or "星期五" in finaltext[w+ww]or "星期四" in finaltext[w+ww]or "星期三" in finaltext[w+ww]or "星期二" in finaltext[w+ww]or "星期一" in finaltext[w+ww]:
                    break
                if "分鐘" in finaltext[w+ww]:
                    finaltext[w+ww]='x'
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "不在學校" in finaltext[w]:
            print(finaltext[w])
            print('------')
            for ww in range(1,10):
                if w+ww ==len(finaltext):
                    break
                if "上午" in finaltext[w+ww] or "下午" in finaltext[w+ww] or "晚上" in finaltext[w+ww]or "星期五" in finaltext[w+ww]or "星期四" in finaltext[w+ww]or "星期三" in finaltext[w+ww]or "星期二" in finaltext[w+ww]or "星期一" in finaltext[w+ww]:
                    break
                if "分鐘" in finaltext[w+ww]:
                    finaltext[w+ww]='x'
    for w in range(len(finaltext)):
        if w == len(finaltext):
            break
        if "早餐" in finaltext[w] or "午餐" in finaltext[w] or "晚餐" in finaltext[w]:
            for ww in range(1,5):
                if w+ww == len(finaltext):
                    break
                if "不在學校" in finaltext[w+ww]:
                    for www in range(1,100):
                        if w+ww+www == len(finaltext):
                            break
                        if "早餐" in finaltext[w+ww+www] or "午餐" in finaltext[w+ww+www] or "晚餐" in finaltext[w+ww+www]:
                            break
                        finaltext[w+ww+www] = 'x' 
    
#    for i in range(len(finaltext)):
 #       if '上午,[不在學校]' in finaltext[i]:
  #          print(i)
    print(finaltext)
    finaltext.append('\n')
    
    finaltext="".join(finaltext)
    print(len(txt))
    print(co)
    print(txt[146])
    print(finaltext)
    
    fp.write(finaltext)



# 寫入 This is a testing! 到檔案

# 關閉檔案
fp.close()
# Out:
# 153
# 154
# 155
# 156
# 157
# ﻿1.請問是哪個學院的老師或學生?
#
# 資訊學院
# 不在學校
# ------
# ['資訊學院', ',', '星期一', ',', '上午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '下午,[CC資訊網路大樓]', ',', '[5-10分鐘]', ',', '晚上,[CC資訊網路大樓]', ',', '[5-10分鐘]', ',', '星期二', ',', '上午,[體育一館]', ',', '[5-10分鐘]', ',', '下午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '晚上,[AA科技大樓]', ',', '[5-10分鐘]', ',', '星期三', ',', '上午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '下午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '星期四', ',', '上午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '下午,[AA科技大樓]', ',', '[5-10分鐘]', ',', '星期五', ',', '上午,[S資訊管理大樓]', ',', '[5-10分鐘]', ',', 'x', ',', ',早餐', ',', '二餐(包含全家)', ',幾點', ',', '8-9時', ',等候時間', ',', '10-20分鐘', ',午餐', ',', '不在學校', 'x', 'x', 'x', 'x', 'x', 'x', ',晚餐', ',', '二餐(包含全家)', ',幾點', ',', '19-20時', ',等候時間', ',', '10-20分鐘']
# 154
# 171
# 二餐(包含全家)
# ...

# %%
w=70
if "早餐" in finaltext[w] or "午餐" in finaltext[w] or "晚餐" in finaltext[w]:
    print('0000')
# Out:
# 0000

# %%
from keras.utils import to_categorical
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn import preprocessing
import re
lb = LabelEncoder()
major=np.array(['資訊學院','觀光學院','健康科技學院','社會科學院','設計學院','教育暨應用語文學院'
              ,'金融科技學院','星期一','星期二','星期三','星期四','星期五','BB','AA','S','P','EE','CC','M','Q','體育一館','體育二館','操場'
                ,'一餐','二餐','三餐','學校宿舍','不在學校','上午','下午','晚上'])
#day = np.array(['星期一','星期二','星期三','星期四','星期五'])
#local = np.array(['BB','AA','S','P','EE','CC','M','Q','體育一館','體育二館','操場'
#                ,'一餐','二餐','三餐','學校宿舍','不在學校'])
time = np.array(['0-5','5-10','10-15','15-20','20分鐘'])
#apm = np.array(['上午','下午','晚上'])
labelen = preprocessing.LabelEncoder
majorlab=lb.fit_transform(major)
timelab=lb.fit_transform(time)

print(majorlab)
print(timelab)


#print(to_categorical(daylab))
#print(to_categorical(majorlab))

f = open('C:/pythonwork/final.txt', "r")
text = []
newxtext=[]
ntext =[]
a=[]
a=np.array(a)
b=[]
b=np.array(b)
b=b[np.newaxis]
c=[]
c=np.array(c)
d=[]
d=np.array(d)

print(d.shape)
fp = open("filename.txt", "a")
c
for w in range(1):#len(text)):
    ntext=text[0].split(',')
    a=[]
    c=[]
    for i in range(len(ntext)):
        if "早餐" in ntext[i] or "午餐" in ntext[i] or "晚餐" in ntext[i]:
            break
        for ww in range(len(major)):
            if major[ww] in ntext[i]:
                a=np.append(a,majorlab[ww])
   
    
        for ww in range(len(time)):
            if time[ww] in ntext[i]:
                c=np.append(c,timelab[ww])
    a=a[np.newaxis] 
    print(a.shape)
    print(b.shape)
    d=np.concatenate((c, d))
    b=np.concatenate((a, b))
        
                
print(b)
print(d)
# Out:
# [27 25 14 24 26 17 28 18 20 19 22 21  1  0  7  5  3  2  4  6 29 30 16  8
#  13  9 15 12 10 11 23]
# [0 4 1 2 3]
# (0,)
# (1, 38)
# (1, 0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-962ee30c572a> in <module>()
#      61     print(b.shape)
#      62     d=np.concatenate((c, d),axis=0)
# ---> 63     b=np.concatenate((a, b),axis=0)
#      64
#      65
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
f = open('C:/pythonwork/final.txt', "r")
ntext=[]
for line in f:
    text.append(line)
for w in range (len(text)):
    ntext ="".join(text[w]).split(',')
    for ww in range (len(ntext)):
            
        
print(ntext)
# Out:
# ['資訊學院', '星期一', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期二', '上午', '[BB社科大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '星期三', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期四', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[S資訊管理大樓]', '[5-10分鐘]', '星期五', '上午', '[AA科技大樓]', '[5-10分鐘]', '下午', '[AA科技大樓]', '[5-10分鐘]', '', '早餐', '二餐(包含全家)', '幾點', '8-9時', '等候時間', '20-30分鐘\n']

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([[9, 8, 7], [6, 5, 4]])
print(a.shape)
# Out:
# (2, 3)

# %%
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6, 9, 8, 7, 6, 5, 4])

# %%
f = open('C:/pythonwork/finaltext.txt', "r")
text=[]
ntext=[]
finaltext=[]
fp = open("final2.txt", "a")
for line in f:
    text.append(line)
for co in range(len(text)):
    ntext=text[co].split(',') 
    for w in range(len(ntext)):
        if len(ntext)== w+5:
            break
        if '上午'in ntext[w] :
            for i in range(2,5):
                if '上午' in ntext[w+i]:
                    ntext[w+i]=''
        if '下午'in ntext[w] :
            for i in range(2,5):
                if '下午' in ntext[w+i]:
                    ntext[w+i]=''
        if '晚上'in ntext[w] :
            for i in range(2,5):
                if '晚上' in ntext[w+i]:
                    ntext[w+i]=''

    finaltext=",".join(ntext)
    fp.write(finaltext)

    finaltext=[]




# 寫入 This is a testing! 到檔案

# 關閉檔案
fp.close()

# %%
f = open('C:/pythonwork/final2.txt', "r")
text=[]
ntext=[]
finaltext=[]
fp = open("final3.txt", "a")
for line in f:
    text.append(line)
for co in range(len(text)):
    ntext=text[co].split(',') 
    for w in range(len(ntext)):
        if 'BB' in ntext[w] or 'AA' in ntext[w] or 'S' in ntext[w] or'P' in ntext[w] or'EE' in ntext[w] or'CC' in ntext[w] or'M' in ntext[w] or'Q' in ntext[w] or'FF' in ntext[w] or'體育一館' in ntext[w] or'室外籃球場' in ntext[w] or'操場' in ntext[w] or'一餐' in ntext[w] or'二餐' in ntext[w] or'三餐' in ntext[w] or'體育二館' in ntext[w] or'學校宿舍' in ntext[w] :
            for ww in range(1,2):
                if ntext[w+ww]== len(ntext):
                    break
                if '分鐘' not in ntext[w+ww]:
                    ntext[w]='x'

    final3=",".join(ntext)
    fp.write(final3)

    final3=[]




# 寫入 This is a testing! 到檔案

# 關閉檔案
fp.close()

# %%
p=[]
if '分鐘' not in p:
    print(":::::::::::::")
# Out:
# :::::::::::::
