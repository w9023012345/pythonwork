# %%
import numpy as np
import os
current=[]
basepath = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09')
print(basepath)
for i in range(len(basepath)):
    
    baseth1 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i])
    #print(baseth1)
    
    for j in range(len(baseth1)):
        baseth2 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j])
        #print(baseth2)
        
        for k in range(len(baseth2)):
            baseth3 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k])
            #print(baseth3)
            for L in range(len(baseth3)):
                print(basepath[i]+"---"+baseth1[j]+'---'+baseth2[k]+'---'+baseth3[L])
                f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k]+'\\'+baseth3[L], 'r')
                #print(f)
                text = []
                
                for line in f:
                    text.append(line)
              
                
                newxtext=[]
                newytext=[]
                ntext=[]
                for q in range(0,len(text)):
                    if 'lat=' in text[q]:
                        ntext =" ".join(text[q]).split('"')
                        newxtext.append(ntext[1])
                        newytext.append(ntext[3])
                if len(newxtext) :           
                    print(newxtext[0])
                    print(newytext[0])
                og = 0
                for w in range (len(newxtext)):
                    if (float(newxtext[w].replace(" ","")) >= 121.341391 and float(newxtext[w].replace(" ","")) <= 121.343406 and float(newytext[w].replace(" ",""))>=24.981274 and float(newytext[w].replace(" ",""))<=24.986525):
                        og = 1
                        
                if og == 1:        
                    current.append(f)  
                    
                text.clear()
                ntext.clear()
                newxtext.clear()
                newytext.clear()    
                f.close()
                
txt=" ".join(current)
print(type(txt))
fp = open("filename.txt", "a")

# 寫入 This is a testing! 到檔案
fp.write(txt)
 
# 關閉檔案
fp.close()

# %%
print(current)
# Out:
# []

# %%
import numpy as np
import os
current=[]
basepath = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09')
print(basepath)
for i in range(len(basepath)):
    
    baseth1 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09\\'+basepath[i])
    #print(baseth1)
    
    for j in range(len(baseth1)):
        baseth2 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j])
        #print(baseth2)
        
        for k in range(len(baseth2)):
            baseth3 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k])
            #print(baseth3)
            for L in range(len(baseth3)):
                print(basepath[i]+"---"+baseth1[j]+'---'+baseth2[k]+'---'+baseth3[L])
                f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k]+'\\'+baseth3[L], 'r')
                #print(f)
                text = []
                
                for line in f:
                    text.append(line)
              
                
                newxtext=[]
                newytext=[]
                ntext=[]
                for q in range(0,len(text)):
                    if 'lat=' in text[q]:
                        ntext =" ".join(text[q]).split('"')
                        newxtext.append(ntext[1])
                        newytext.append(ntext[3])
                if newxtext != None :           
                    print(newxtext[0])
                    print(newytext[0])
                og = 0
                for w in range (len(newxtext)):
                    if (float(newxtext[w].replace(" ","")) >= 121.341391 and float(newxtext[w].replace(" ","")) <= 121.343406 and float(newytext[w].replace(" ",""))>=24.981274 and float(newytext[w].replace(" ",""))<=24.986525):
                        og = 1
                        
                if og == 1:        
                    current.append(f)  
                    
                text.clear()
                ntext.clear()
                newxtext.clear()
                newytext.clear()    
                f.close()
                
txt=" ".join(current)
print(type(txt))
fp = open("filename.txt", "a")

# 寫入 This is a testing! 到檔案
fp.write(txt)
 
# 關閉檔案
fp.close()

# %%
import numpy as np
import os
current=[]
basepath = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\nnewgpx-planet-2013-04-09')
print(basepath)
for i in range(len(basepath)):
    
    baseth1 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\nnewgpx-planet-2013-04-09\\'+basepath[i])
    #print(baseth1)
    
    for j in range(len(baseth1)):
        baseth2 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\nnewgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j])
        #print(baseth2)
        
        for k in range(len(baseth2)):
            baseth3 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\nnewgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k])
            #print(baseth3)
            for L in range(len(baseth3)):
                print(basepath[i]+"---"+baseth1[j]+'---'+baseth2[k]+'---'+baseth3[L])
                f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\nnewgpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k]+'\\'+baseth3[L], 'r')
                #print(f)
                text = []
                
                for line in f:
                    text.append(line)
              
                
                newxtext=[]
                newytext=[]
                ntext=[]
                for q in range(0,len(text)):
                    if 'lat=' in text[q]:
                        ntext =" ".join(text[q]).split('"')
                        newxtext.append(ntext[1])
                        newytext.append(ntext[3])
                if len(newxtext) :        
                    print(newxtext[0])
                    print(newytext[0])
                og = 0
                for w in range (len(newxtext)):
                    if (float(newxtext[w].replace(" ","")) >= 121.341391 and float(newxtext[w].replace(" ","")) <= 121.343406 and float(newytext[w].replace(" ",""))>=24.981274 and float(newytext[w].replace(" ",""))<=24.986525):
                        og = 1
                        
                if og == 1:        
                    current.append(f)  
                    
                text.clear()
                ntext.clear()
                newxtext.clear()
                newytext.clear()    
                f.close()
                
txt=" ".join(current)
print(type(txt))
fp = open("filename.txt", "a")

# 寫入 This is a testing! 到檔案
fp.write(txt)
 
# 關閉檔案
fp.close()

# %%
newxtext=[]
if newxtext != None :
    print("123")
# Out:
# 123

# %%
import numpy as np
import os
current=[]

f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\newgpx-planet-2013-04-09\\public\\001\\422\\001422253.gpx', 'r')
text = []
                
for line in f:
    text.append(line)
              
                
newxtext=[]
newytext=[]
ntext=[]
for q in range(0,len(text)):
     if 'lat=' in text[q]:
        ntext =" ".join(text[q]).split('"')
        newxtext.append(ntext[1])
        newytext.append(ntext[3])
                        
if len(newxtext) :       
    print(newxtext[0])
    print(newytext[0])
og = 0
for w in range (len(newxtext)):
    if (float(newxtext[w].replace(" ","")) >= 121.341391 and float(newxtext[w].replace(" ","")) <= 121.343406 and float(newytext[w].replace(" ",""))>=24.981274 and float(newytext[w].replace(" ",""))<=24.986525):
        og = 1
                        
if og == 1:        
    current.append(f)  
                    
text.clear()
ntext.clear()
newxtext.clear()
newytext.clear()    
f.close()
                
txt=" ".join(current)
print(type(txt))
fp = open("filename.txt", "a")

# 寫入 This is a testing! 到檔案
fp.write(txt)
 
# 關閉檔案
fp.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-e4652eb47f4a> in <module>()
#      20
#      21 if newxtext != None :
# ---> 22     print(newxtext[0])
#      23     print(newytext[0])
#      24 og = 0
#
# IndexError: list index out of range

# %%
newxtext=[]
newxtext.clear()
if len(newxtext) :
    print("123")
