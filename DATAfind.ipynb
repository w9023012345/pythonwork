# %%
import numpy as np
import os

basepath = os.listdir('C:\\Users\\schoolpc\\Desktop\\Data\\')
current=[]
for i in range(len(basepath)):
    #print(i)
    baseth1 = os.listdir('C:\\Users\\schoolpc\\Desktop\\Data\\'+basepath[i]+'\\Trajectory')
    #print(baseth1)
    
    for j in range(len(baseth1)):
        print(basepath[i]+"---"+baseth1[j])
        f = open('C:\\Users\\schoolpc\\Desktop\\Data\\'+basepath[i]+'\\Trajectory\\'+baseth1[j], 'r')
        
        #print(f)
        text = []
       
        for line in f:
            text.append(line)
       

        text = text[6:]
        print(text[1])
        
        newxtext=[]
        newytext=[]
        for q in range(len(text)):
            ntext =" ".join(text[q]).split(',')
            newxtext.append(ntext[1])
            newytext.append(ntext[0])

            
        for w in range (len(newxtext)):
            if (float(newxtext[w].replace(" ","")) >= 121.341391 and float(newxtext[w].replace(" ","")) <= 121.343406 and float(newytext[w].replace(" ",""))>=24.981274 and float(newytext[w].replace(" ",""))<=24.986525):
                current.append(f)
                
        text.clear()
        newxtext.clear()
        newytext.clear()
        
print(current)
# Out:
# 000---20081023025304.plt
# 39.984683,116.31845,0,492,39744.1202546296,2008-10-23,02:53:10
#
# 000---20081024020959.plt
# 40.008413,116.319962,0,491,39745.0903240741,2008-10-24,02:10:04
#
# 000---20081026134407.plt
# 39.907374,116.370074,0,93,39747.5723611111,2008-10-26,13:44:12
#
# 000---20081027115449.plt
# 39.994622,116.326757,0,492,39748.4964351852,2008-10-27,11:54:52
#
# 000---20081028003826.plt
# 40.012594,116.297269,0,490,39749.0267476852,2008-10-28,00:38:31
#
# 000---20081029092138.plt
# 39.994315,116.326758,0,492,39750.3900810185,2008-10-29,09:21:43
#
# 000---20081029093038.plt
# 39.991551,116.326653,0,163,39750.3963310185,2008-10-29,09:30:43
#
# 000---20081103101336.plt
# 40.000032,116.326175,0,492,39755.4261689815,2008-11-03,10:13:41
#
# 000---20081103232153.plt
# 39.996849,116.325763,0,491,39755.973587963,2008-11-03,23:21:58
#
# 000---20081110013637.plt
# 39.997666,116.32653,0,96,39762.0671527778,2008-11-10,01:36:42
#
# 000---20081111001704.plt
# ...

# %%
import numpy as np
import os

basepath = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09')
print(basepath)
for i in range(len(basepath)):
    
    baseth1 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i])
    print(baseth1)
    
    for j in range(len(baseth1)):
        baseth2 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j])
        print(baseth2)
        
        for k in range(len(baseth2)):
            baseth3 = os.listdir('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k])
            print(baseth3)
            for L in range range(len(baseth3))
                f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\'+basepath[i]+'\\'+baseth1[j]+'\\'+baseth2[k]+'\\'+baseth3[L], 'r')
                print(f(0))

# %%
import re
f = open('C:\\Users\\schoolpc\\Documents\\EGDownloads\\gpx-planet-2013-04-09\\identifiable\\000\\001\\000001605.gpx')
for line in f:
    text.append(line)
print (text)
# Out:
# ['40.011532,116.321628,0,-681,39914.2249768519,2009-04-11,05:23:58\n', '40.011274,116.321454,0,95,39914.2250347222,2009-04-11,05:24:03\n', '40.011415,116.321873,0,-457,39914.2250925926,2009-04-11,05:24:08\n', '40.011185,116.321966,0,61,39914.225150463,2009-04-11,05:24:13\n', '40.011163,116.32206,0,24,39914.2252083333,2009-04-11,05:24:18\n', '40.010962,116.322471,0,672,39914.2252662037,2009-04-11,05:24:23\n', '40.010879,116.322446,0,639,39914.2253240741,2009-04-11,05:24:28\n', '40.010911,116.322409,0,662,39914.2253819444,2009-04-11,05:24:33\n', '40.011225,116.321887,0,-83,39914.2254398148,2009-04-11,05:24:38\n', '40.011472,116.321508,0,-579,39914.2254976852,2009-04-11,05:24:43\n', '40.011602,116.321318,0,-812,39914.2255555556,2009-04-11,05:24:48\n', '40.011544,116.321435,0,-682,39914.2256134259,2009-04-11,05:24:53\n', '40.011402,116.321661,0,-361,39914.2256712963,2009-04-11,05:24:58\n', '40.011313,116.321693,0,-168,39914.2257291667,2009-04-11,05:25:03\n', '40.01124,116.321763,0,-9,399
# ...

# %%
count=['1','1','1','1','1']
print(type(count))
txt=" ".join(count)
print(type(txt))
fp = open("filename.txt", "a")

# 寫入 This is a testing! 到檔案
fp.write(txt)
 
# 關閉檔案
fp.close()
# Out:
# <class 'list'>
# <class 'str'>
